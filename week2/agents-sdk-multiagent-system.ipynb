# %%
import agents
from dotenv import load_dotenv
# from openai import OpenAI
# openai_client = OpenAI()
load_dotenv()
# Out:
# True

# %%
from agents import Agent, function_tool, Runner
from agents import Runner

# %%
runner = Runner()
from toyaikit.chat import IPythonChatInterface
from toyaikit.chat.runners import OpenAIAgentsSDKRunner

chat_interface = IPythonChatInterface()

# %% [markdown]
# ### Summary Agent

# %%
# Youtube video

import youtube

subtitles = youtube.fetch_youtube_transcript('vK_SxyqIfwk')
print(subtitles[:500])
# Out:
# 0:00 Hey everyone, welcome to our event. This
# 0:02 event is brought to you by data talks
# 0:03 club which is a community of people who
# 0:05 love data. We have weekly events today.
# 0:08 Uh this is one of such events. Um if you
# 0:11 want to find out more about the events
# 0:13 we have, there is a link in the
# 0:14 description. Um so click on that link,
# 0:16 check it out right now. We actually have
# 0:19 quite a few events in our pipeline, but
# 0:21 we need to put them on the website. Uh
# 0:24 but keep a

# %%
summary_instructions = """
You're a helpful assistant that helps answer user questions
about YouTube videos
"""

# %%
summary_agent = Agent(
    name='summary_agent',
    instructions=summary_instructions,
    handoff_description="Whenever the user needs a summary of the video",
    tools=[function_tool(youtube.fetch_youtube_transcript)],
    model='gpt-4o-mini'
)

# %% [markdown]
# ### Search Agent

# %%
from minsearch import AppendableIndex
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import docs

# %%
index = AppendableIndex(text_fields=['content'])

# %%
# Create the function

# %%
from typing import Any, Dict, List, Optional
from requests.exceptions import RequestException

# how do you know which agent are you going to create, and what is the function needed


class SearchTools:

    def __init__(self, index: Any) -> None:
        self.index = index

    def index_video(self, video_id: str, content: Optional[str] = None) -> bool:
        """
        Fetch and index the transcript of a YouTube video.

        Args:
            video_id (str): The unique identifier of the YouTube video.

        Returns:
            bool: True if indexing succeeds, False otherwise.
        """
        try:
            if not content:
                content = youtube.fetch_youtube_transcript(video_id)
                if not content:
                    print(f"No subtitles found for video: {video_id}")
                    return False

            chunks = docs.sliding_window(content, 2000, 1000)
            for chunk in chunks:
                chunk["video_id"] = video_id
                self.index.append(chunk)

            return True

        except (RequestException, ValueError) as e:
            print(f"Error indexing video {video_id}: {e}")
            return False
        except AttributeError:
            print("Error: 'youtube' or 'docs' module not properly configured.")
            return False
        except Exception as e:
            print(f"Unexpected error during indexing: {e}")
            return False

    def search(self, query: str) -> Dict[str, Any]:
        """
        Search for relevant results in the indexed video transcripts.

        Args:
            query (str): The user's search query.

        Returns:
            Dict[str, Any]: A dictionary containing the top search results.
        """
        if not isinstance(query, str) or not query.strip():
            raise ValueError("Query must be a non-empty string.")

        try:
            results = self.index.search(query, num_results=5)
            return results
        except AttributeError:
            raise AttributeError("Index object must implement a 'search(query, num_results=...)' method.")
        except Exception as e:
            print(f"Error performing search: {e}")
            return {}

# %%
search_tools = SearchTools(index)

# %%
from toyaikit.tools import wrap_instance_methods

search_method_tools = wrap_instance_methods(function_tool, search_tools)

# %%
# search_method_tools = [function_tool(search_tools.index_video), 
#                        function_tool(search_tools.search)
#                       ]

# %%
# search_tools.index_video('vK_SxyqIfwk')

# %%
# search_tools.search('tesla')

# %%
search_instructions = """
Your task is to search through indexed documents.

Before performing a search:

1. Check if the document has been indexed.
2. If not, call `index_video` to index it.

Important rules:

- Do NOT call `search` using a YouTube ID, webpage URL, or any direct link as the query.
- After successfully indexing a source, do NOT perform a search automatically.
- Instead, tell the user something like:
  "The video (or page) has been indexed. What would you like to learn about it?"

Only perform a search if the user provides a natural-language question or topic of interest
(e.g., "What does the video say about AI safety?"), not a URL or ID.

Do not attempt to summarize content.
"""

search_agent = Agent(
    name='search_agent',
    instructions=summary_instructions,
    handoff_description="Whenever the user needs a summary of the video",
    tools=search_method_tools,
    model='gpt-4o-mini'
)

# %%
runner = OpenAIAgentsSDKRunner(
    chat_interface=chat_interface,
    agent=search_agent
)

# %%
await runner.run();
# Out:
# You: stop
# Chat ended.

# %% [markdown]
# ### Summary Agent Updated

# %%
import youtube

# %%
class SummaryTools:

    def __init__(self, search_tools):
        self.search_tools = search_tools

    def fetch_youtube_transcript(self, video_id: str) -> str:
        """
        Fetches the transcript of a YouTube video and converts it into a subtitle-formatted string.
    
        Args:
            video_id (str): The unique YouTube video ID.
    
        Returns:
            str: The subtitles generated from the video's transcript.
        """
        content = youtube.fetch_youtube_transcript(video_id)
        self.search_tools.index_video(video_id, content)
        return content

# %%
summary_tools = SummaryTools(search_tools)

# %%
summary_instructions = """
You're a helpful assistant that summarizes youtube videos
"""

# %%
summary_agent = Agent(
    name='summary_agent',
    instructions=summary_instructions,
    handoff_description="Whenever the user needs a summary of the video",
    tools=[function_tool(summary_tools.fetch_youtube_transcript)],
    model='gpt-4o-mini'
)

# %%
from agents import Runner
runner = Runner()

result = await runner.run(summary_agent, input='What is this video about https://www.youtube.com/watch?v=ZFrcrTtnB1Q?')

# %%
result.new_items[0].raw_item
# Out:
# ResponseFunctionToolCall(arguments='{"video_id":"ZFrcrTtnB1Q"}', call_id='call_4XeMqlcuQVgu6CKUNQeNJQbN', name='fetch_youtube_transcript', type='function_call', id='fc_07b8895ee59a73930068f1bc0bb83c8196b4508f27efeb64ba', status='completed')

# %% [markdown]
# ### Triage / Orchestrator

# %%
from agents import handoff

# %%
triage_instructions = """
You are the orchestrator between two specialized agents:

1. summarizing_agent — summarizes web pages or YouTube videos.
2. search_agent — searches within previously indexed documents to answer detailed or follow-up questions.

Routing rules:

- If the user sends a YouTube link without any question → hand off to summary_agent.
- If the user asks for a summary, overview, or "what is this video about" → summary_agent.
- If the user asks a follow-up question after a summary (e.g. "how did they do X?", "what does she say about Y?"),
  or refers to something mentioned in a previously summarized or indexed resource → hand off to search_agent.
- If the user asks a direct content question about a topic inside a resource → search_agent.
- Prefer delegating the answer to agents when possible. 

Examples:
User: "https://youtube.com/watch?v=abc123"
→ summary_agent

User: "What does the video say about climate change?"
→ search_agent

User: "How exactly did they fight malaria?" (after a summary)
→ search_agent
""".strip()

triage_agent = Agent(
    name='triage_agent',
    instructions=triage_instructions,
    handoffs=[
        handoff(summary_agent, on_handoff=lambda ctx: print('handoff to summary agent')),
        handoff(search_agent, on_handoff=lambda ctx: print('handoff to search agent')),
    ],
    model='gpt-4o-mini'
)

# %%
runner = OpenAIAgentsSDKRunner(
    chat_interface=chat_interface,
    agent=triage_agent
)

# %%
"""
handoff to summary agent
handoff: transfer_to_summary_agent
handoff: summary_agent -> triage_agent successful

Question - how does this handoff to each other? - toyaikit package

"""
# Out:
# '\nhandoff to summary agent\nhandoff: transfer_to_summary_agent\nhandoff: summary_agent -> triage_agent successful\n\nQuestion - how does this handoff to each other?\n\n'

# %%
await runner.run();
# Out:
# You: What is this video about https://www.youtube.com/watch?v=ZFrcrTtnB1Q?
# handoff to summary agent
# handoff: transfer_to_summary_agent
# handoff: summary_agent -> triage_agent successful
#             <details>
#             <summary>Function call: <tt>fetch_youtube_transcript({"video_id":"ZFrcrTtnB1Q"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"video_id":"ZFrcrTtnB1Q"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>0:00 Hi everyone, welcome to our event. This
# 0:02 event is brought to you by Data Talks
# 0:03 Club which is a community of people who
# 0:05 love data. We have weekly events and
# 0:07 today is one of such events. If you want
# 0:10 to find out more about the events we
# 0:11 have, there is a link in the
# 0:13 description.
# 0:14 Looks like that. So click on it. Um
# 0:17 check it out. We have quite a few events
# 0:18 in our pipeline.
# 0:20 Then do not forget to subscribe to our
# 0:22 YouTube channel. This way you'll get
# 0:24 notifications about all future streams
# 0:26 like the one we have today. Last but not
# 0:28 least, we have an amazing Slack
# 0:29 community where you can hang out with
# 0:30 other data enthusiasts. So the link is
# 0:32 also in the description. During today's
# 0:34 interview, you can ask any question you
# 0:36 want. Uh there is a pinned link in the
# 0:38 live chat. Click on that link, ask your
# 0:40 questions and I will we will be covering
# 0:42 these questions during the interview.
# 0:46 So that's the usual introduction. Um
# 0:50 I have the questions.
# 0:53 Um
# 0:55 and
# 0:58 I have um the questions on the left side
# 1:01 and zoom on the right side. So I'm ready
# 1:02 to start. Is if Sebastian you ready? We
# 1:05 can do it.
# 1:08 >> Yes.
# 1:10 >> So hi everyone. Uh this week we are
# 1:12 joined by Sebastian a bioinformatics
# 1:15 software engineer whose career bridges
# 1:17 biotechnology and programming. Sebastian
# 1:20 began in biotechnology engineering but
# 1:22 realized uh um just research wasn't his
# 1:25 path. Uh through a minor in software
# 1:28 engineering and master's degree
# 1:29 combining both fields he transitioned
# 1:31 into bioinformatics software
# 1:33 engineering. Um so we will I will ask
# 1:36 you more about these things and I'm
# 1:38 really happy to have you here on this
# 1:39 podcast.
# 1:42 >> Thank you very much.
# 1:44 >> Yeah. Uh yeah. So let's start the
# 1:47 question. Um the usually the first
# 1:49 question I always ask is to tell us more
# 1:52 about your career journey so far. I
# 1:54 outlined it briefly um to me I don't
# 1:58 know anything about biotechnology and
# 2:00 bio bio informatics except maybe one
# 2:02 course that I took on Corsera like 12
# 2:04 years ago but anyways so tell us about
# 2:07 your career journey so far.
# 2:09 >> Yes. So yeah I did my bachelor's here in
# 2:13 Ecuador. So I studied biotechnology
# 2:16 engineering which basically is the
# 2:19 application of living organisms to
# 2:22 different
# 2:24 in different areas. So you can apply it
# 2:26 to kind of develop new potential drugs
# 2:30 or to kind of in agriculture
# 2:34 and all of the applications are based on
# 2:37 living organisms. it can be in in
# 2:40 different parts and
# 2:43 then while I was doing my bachelors I
# 2:47 realized that I didn't like that much
# 2:49 that and the wet lab and biology and
# 2:52 this stuff so I started to take some
# 2:55 electives on programming and maths and I
# 2:59 kind of I like that more that approach
# 3:02 so I kind of did a minor in software
# 3:04 engineering
# 3:06 yeah and then in my masters I combine
# 3:08 both in binformatics and during the last
# 3:10 year I've been working more on software
# 3:12 development for the bionirmatics.
# 3:17 >> And you said you just finished your
# 3:19 project which was in Denmark and you
# 3:20 moved to Ecuador to spend the winter
# 3:22 there. Amazing idea. Yeah. So I live in
# 3:25 Berlin. So I can imagine what it is like
# 3:29 now in Denmark. Uh so I think it's even
# 3:33 worse than in Berlin cuz it's like by
# 3:34 the sea, closer to the sea. So yeah,
# 3:37 good idea spending time in Ecuador. Um
# 3:39 but um what exactly was your project
# 3:41 about? I don't know to what extent you
# 3:43 can talk about this, but was it pure
# 3:45 software engineering? Was it
# 3:46 bioinformatics? What do you actually do
# 3:49 now?
# 3:50 >> Yeah. Uh during the the last projects
# 3:53 that I worked during the la basically is
# 3:56 like I first I did my masters in the
# 3:59 Netherlands. I forgot to mention that in
# 4:01 bionopromatics and I did my master
# 4:03 thesis abroad like with my supervisor in
# 4:06 Denmark at
# 4:09 the technical university of Denmark and
# 4:14 during my master thesis I work in a
# 4:17 project that we call MCW2 graph. So
# 4:20 basically this is a knowledge graph to
# 4:22 investigate the wastewater treatment
# 4:24 microbiome. So basically a microbiome is
# 4:28 kind of the kind of all of the
# 4:31 microorganisms that live in a specific
# 4:33 environment. So what we did is like
# 4:37 usually like people take samples from
# 4:40 different environments in this case
# 4:43 wastewater treatment plants and then
# 4:46 they take samples and then they sequence
# 4:48 all of the kind the DNA or the proteins
# 4:51 that are inside this environment. And
# 4:53 then when you kind of process this data
# 4:56 you can see like the presence of
# 4:59 different the presence and abundance of
# 5:01 microorganisms in these samples. So what
# 5:04 we did is that we took kind of studies
# 5:07 from different kind of regions around
# 5:11 the world, different wastewater
# 5:12 treatments all over the world and then
# 5:14 we combine this data and then we imper
# 5:17 kind of these microbial association
# 5:19 networks we call. So it's like
# 5:22 correlation networks based on abundance
# 5:25 patterns. So based on co-abundance let's
# 5:28 say that we find a microorganism in this
# 5:31 sample and the same like another
# 5:34 microorganisms is also present in this
# 5:36 sample with a similar abundance. So we
# 5:39 kind of we infer that they are kind of
# 5:43 interacting somehow. So we created this
# 5:47 kind of networks and then we build a
# 5:49 knowledge gra on top of that with
# 5:51 additional metadata.
# 5:53 Yeah, that was my first project there
# 5:56 and then I work on others.
# 5:59 >> Yeah, I'm taking notes so I can ask you
# 6:02 later about these things. But uh for me
# 6:04 I know nothing about biotechnology.
# 6:07 >> Mhm. Um so when COVID happened right and
# 6:12 everyone was uh freaking out and then
# 6:14 people companies started to develop
# 6:16 vaccines. So do people like is
# 6:20 biotechnology involved there for
# 6:24 >> like how exactly does it work? Yeah,
# 6:27 actually it's like um so because you do
# 6:31 the experiments on on the lab to test
# 6:35 like the different
# 6:37 vaccines and how different compounds
# 6:40 kind of
# 6:42 can kill or combat the bacteria or the
# 6:45 viruses and you do that in the in the
# 6:50 lab. and and that is kind of
# 6:52 biotechnology and you design different
# 6:54 like components that are more efficient
# 6:56 to combat the viruses and and bacteria
# 6:58 and then bionirmatics
# 7:01 enters
# 7:03 here like to kind of reduce the amount
# 7:06 of experiments that you need to do on
# 7:08 the web lab. So you can do some
# 7:10 simulations or you can analyze the the
# 7:13 data to kind of propose potential
# 7:15 candidates that the people on the web
# 7:18 can test. So you reduce the time and you
# 7:22 propose some potential candidates that
# 7:24 in the end like the wet lab people test.
# 7:28 >> Yeah. I see. I think you have a slight
# 7:30 problem with um sound. Uh are you do you
# 7:34 use your uh headphones microphone?
# 7:38 >> Yeah. Uh I can
# 7:39 >> you can switch to
# 7:43 Can you try now?
# 7:46 I cannot hear you.
# 7:50 I'm sorry everyone. Um, but yeah, just
# 7:52 the sound is breaking a little.
# 7:58 Sorry. Now I switch to the my
# 8:03 laptop. Uh,
# 8:04 >> I think it's better. Yeah, cuz like the
# 8:06 the the sound was breaking a little like
# 8:09 every 3 seconds. That's why I thought
# 8:11 maybe it's like Bluetooth artifact.
# 8:14 >> Okay. Yeah, let's try. I think it's
# 8:16 better. So you were saying that um this
# 8:20 is what biotechnology
# 8:23 uh people who work in biotechnology this
# 8:25 is what they do especially when it comes
# 8:26 to like
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>The video features a discussion centered around bioinformatics and biotechnology. The event, hosted by Data Talks Club, includes an interview with Sebastian, a bioinformatics software engineer, who shares insights into his career pathway and experiences.</p>
# <h3>Key Points Covered:</h3>
# <ol>
# <li><p><strong>Introduction to Bioinformatics</strong>:</p>
# <ul>
# <li>Bioinformatics merges biology with computational techniques to analyze biological data, whereas biotechnology focuses more on applying biological organisms in various fields.</li>
# </ul>
# </li>
# <li><p><strong>Sebastian's Background</strong>:</p>
# <ul>
# <li>He transitioned from biotechnology to bioinformatics through a minor in software engineering and a master’s program that combined both fields.</li>
# </ul>
# </li>
# <li><p><strong>Projects Discussed</strong>:</p>
# <ul>
# <li>Sebastian shares about his master's project on a knowledge graph for investigating the microbiome in wastewater treatment, discussing how microbial associations and correlations can inform on interactions between microorganisms.</li>
# </ul>
# </li>
# <li><p><strong>Real-World Applications</strong>:</p>
# <ul>
# <li>Discusses the role of biotechnology in vaccine development, especially during the COVID-19 pandemic, highlighting the dry lab and wet lab distinction.</li>
# </ul>
# </li>
# <li><p><strong>Use of Data Science</strong>:</p>
# <ul>
# <li>Explains how he employs data science methodologies to process and analyze biological data, particularly the use of correlation and predictive models in bioinformatics.</li>
# </ul>
# </li>
# <li><p><strong>Tools and Technologies</strong>:</p>
# <ul>
# <li>Highlights the use of various tools such as Python packages for report generation and data visualization, as well as his experiences with some recent projects that aim to improve bioinformatics workflows.</li>
# </ul>
# </li>
# <li><p><strong>Significance of AI in Bioinformatics</strong>:</p>
# <ul>
# <li>Mentions the growing impact of AI and Machine Learning in bioinformatics for data handling and analysis, alongside traditional methodologies.</li>
# </ul>
# </li>
# <li><p><strong>Engagement with Audience</strong>:</p>
# <ul>
# <li>Questions from viewers about beginner-friendly projects in bioinformatics, useful resources, and how AI tools can assist in the field displayed a keen interest in how to get started and excel in bioinformatics.</li>
# </ul>
# </li>
# </ol>
# <p>The video not only provides insights into the career journey of a bioinformatics engineer but also emphasizes the importance of interdisciplinary skills combining biology, data science, and programming to address current challenges in the life sciences.</p>
# </div>
#             </div>
# You: stop
# Chat ended.
