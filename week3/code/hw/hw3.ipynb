# %%
# Serach  - search multple search key words
# Get page - use that key word to get page

# %%
# Q4 - .py structure
# Q5 - Test and the output [utest]
# Q6 - Create ground truth data

# %%
from pydantic_ai import Agent
from pydantic import BaseModel, Field
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import requests

# %%
key_word = 'capybara'
search_keyword = "+".join(key_word.split(" "))
search_keyword
# Out:
# 'capybara'

# %%
url = f'https://en.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch={search_keyword}'
url = f'https://en.wikipedia.org/w/index.php?title={search_keyword}&action=raw'

# json format -> search multiple keywords
# split on '\n\n'

response = requests.get(url,  headers={"User-Agent": "Mozilla/5.0"})

response.raise_for_status()  # Raises HTTPError for bad status codes
response.content.decode("utf-8")
# Out:
# '{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name="iucn status 19 November 2021">{{cite iucn |author=Reid, F. |date=2016 |title=\'\'Hydrochoerus hydrochaeris\'\' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petrópolis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petrópolis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = \'\'Sus hydrochaeris\'\' {{small|Linnaeus,&nbsp;1766}}\n}}\n\nThe \'\'\'capybara\'\'\'{{efn | Also referred as \'\'\'capivara\'\'\' (in Brazil), \'\'\'capiguara\'\'\' (in Bolivia), \'\'\'chigüire\'\'\', \'\'\'chigüiro\'\'\', or \'\'\'fercho\'\'\' (in Colombia and Venezuela), \'\'\'carpincho\'\'\' (in Argentina, Paraguay and Uruguay) and \'\'\'ronsoco\'\'\' (in Peru).}} or \'\'\'greater capybara\'\'\' (\'\'\'\'\'Hydrochoerus hydrochaeris\'\'\'\'\') is the largest living rodent,<ref>{{Cite web | author= Basic Biology | date= 2015 | title= Rodents | url= https://basicbiology.net/animal/mammals/rodents}}</ref> native to [[South America]]. It is a member of the genus \'\'[[Hydrochoerus]]\'\'. Its close relatives include\n[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. The capybara is hunted for its meat and hide and also for grease from its thick fatty skin.<ref>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (\'\'Hydrochoerus hydrochaeris\'\')] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ |date=2012-01-03 }}. ARKive.org</ref>\n\n==Etymology==\nIts common name is derived from [[Tupi language|Tupi]] {{lang|tpn|ka\'apiûara}}, a complex agglutination of {{lang|tpn|kaá}} (leaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent nouns), meaning "one who eats slender leaves", or "grass-eater".<ref>Ferreira, A. B. H. (1986) \'\'[[Novo Dicionário da Língua Portuguesa]]\'\', 2nd ed., Rio de Janeiro: Nova Fronteira, p.344</ref> The [[genus name]], \'\'hydrochoerus\'\', comes from [[Ancient Greek|Greek]] {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the species name, \'\'hydrochaeris\'\', comes from Greek {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χαίρω}} (\'\'{{lang|grc-Latn|chairo}}\'\' "feel happy, enjoy").<ref name=msw3>{{MSW3 Woods|id=13400218|page=1556}}</ref><ref name="inDarwin">{{Cite book | last=Darwin | first=Charles R. | author-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Ships Adventure and Beagle between the years 1826 and 1836, describing their examination of the southern shores of South America, and the Beagle\'s circumnavigation of the globe. Journal and remarks. 1832–1836. | title-link =The Voyage of the Beagle| place =London | publisher =[[Henry Colburn]] | page=619}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'\' (the water-hog), is here also common."\n* See it also in [http://darwin-online.org.uk/content/frameset?itemID=F10.3&viewtype=side&pageseq=1 The Complete Work  ...

# %%
json_response = response.json()

keyword_list = []
for search in json_response['query']['search']:
    key_word = "+".join(search['title'].split(" "))
    keyword_list.append(key_word)

keyword_list
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/Project/ai-bootcamp/week3/code/.venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     334 """Return the Python representation of ``s`` (a ``str`` instance
#     335 containing a JSON document).
#     336
#     337 """
# --> 338 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339 end = _w(s, end).end()
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/json/decoder.py:354, in JSONDecoder.raw_decode(self, s, idx)
#     353 try:
# --> 354     obj, end = self.scan_once(s, idx)
#     355 except StopIteration as err:
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 json_response = response.json()
#       3 keyword_list = []
#       4 for search in json_response['query']['search']:
#
# File ~/Desktop/Project/ai-bootcamp/week3/code/.venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
response.text.split('\n\n')
# Out:
# ['{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name="iucn status 19 November 2021">{{cite iucn |author=Reid, F. |date=2016 |title=\'\'Hydrochoerus hydrochaeris\'\' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petrópolis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petrópolis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = \'\'Sus hydrochaeris\'\' {{small|Linnaeus,&nbsp;1766}}\n}}',
#  "The '''capybara'''{{efn | Also referred as '''capivara''' (in Brazil), '''capiguara''' (in Bolivia), '''chigüire''', '''chigüiro''', or '''fercho''' (in Colombia and Venezuela), '''carpincho''' (in Argentina, Paraguay and Uruguay) and '''ronsoco''' (in Peru).}} or '''greater capybara''' ('''''Hydrochoerus hydrochaeris''''') is the largest living rodent,<ref>{{Cite web | author= Basic Biology | date= 2015 | title= Rodents | url= https://basicbiology.net/animal/mammals/rodents}}</ref> native to [[South America]]. It is a member of the genus ''[[Hydrochoerus]]''. Its close relatives include\n[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. The capybara is hunted for its meat and hide and also for grease from its thick fatty skin.<ref>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (''Hydrochoerus hydrochaeris'')] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ |date=2012-01-03 }}. ARKive.org</ref>",
#  '==Etymology==\nIts common name is derived from [[Tupi language|Tupi]] {{lang|tpn|ka\'apiûara}}, a complex agglutination of {{lang|tpn|kaá}} (leaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent nouns), meaning "one who eats slender leaves", or "grass-eater".<ref>Ferreira, A. B. H. (1986) \'\'[[Novo Dicionário da Língua Portuguesa]]\'\', 2nd ed., Rio de Janeiro: Nova Fronteira, p.344</ref> The [[genus name]], \'\'hydrochoerus\'\', comes from [[Ancient Greek|Greek]] {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the species name, \'\'hydrochaeris\'\', comes from Greek {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χαίρω}} (\'\'{{lang|grc-Latn|chairo}}\'\' "feel happy, enjoy").<ref name=msw3>{{MSW3 Woods|id=13400218|page=1556}}</ref><ref name="inDarwin">{{Cite book | last=Darwin | first=Charles R. | author-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Ships Adventure and Beagle between the years 1826 and 1836, describing their examination of the southern shores of South America, and the Beagle\'s circumnavigation of the globe. Journal and remarks. 1832–1836. | title-link =The Voyage of the Beagle| place =London | publisher =[[Henry Colburn]] | page=619}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'\' (the water-hog), is here also common."\n* See it also in [http://darwin-online.org.uk/content/frameset?itemID=F10.3&viewtype=side&pageseq=1 The Complete Work of Charles Darwin Online]</ref>',
#  '==Classification and phylogeny==\nThe capybara and the [[lesser capybara]] both belong to the subfamily [[Hydrochoerinae]] along with the [[Kerodon|rock cavies]]. The living capybaras and their extinct relatives were previously classified in their own family Hydrochoeridae.<ref name=r4/> Since 2002, molecular phylogenetic studies have recognized a close relationship between \'\'Hydrochoerus\'\' and \'\'[[Kerodon]]\'\', the rock cavies,<ref name="Rowe 2002"/> supporting placement of both genera in a subfamily of [[Caviidae]].<ref name=msw3/>',
#  'Paleontological classifications previously used Hydrochoeridae for all capybaras, while using Hydrochoerinae for the living genus and its closest fossil relatives, such as \'\'[[Neochoerus]]\'\',<ref name="Vucetich 2005"/><ref name="Deschamp 2007"/> but more recently have adopted the classification of Hydrochoerinae within Caviidae.<ref name="Cerdeño 2019">{{cite journal|last1=Cerdeño |first1=E. |last2=Pérez |first2=M.E. |last3=Deschamps |first3=C.M. |last4=Contreras |first4=V.H. |year=2019 |title=A new capybara from the late Miocene of San Juan Province, Argentina, and its phylogenetic implications |journal=Acta Palaeontologica Polonica |volume=64 |issue=1 |pages=199–212 |doi=10.4202/app.00544.2018|doi-access=free |hdl=11336/117299 |hdl-access=free }}</ref> The taxonomy of fossil hydrochoerines is also in a state of flux. In recent years, the diversity of fossil hydrochoerines has been substantially reduced.<ref name="Vucetich 2005"/><ref name="Deschamp 2007"/> This is largely due to the recognition that capybara molar teeth show strong variation in shape over the life of an individual. In one instance, material once referred to four genera and seven species on the basis of differences in molar shape is now thought to represent differently aged individuals of a single species, \'\'Cardiatherium paranense\'\'.<ref name="Vucetich 2005"/>\nAmong fossil species, the name "capybara" can refer to the many species of Hydrochoerinae that are more closely related to the modern \'\'Hydrochoerus\'\' than to the "cardiomyine" rodents like \'\'Cardiomys\'\'. The fossil genera \'\'Cardiatherium\'\', \'\'Phugatherium\'\', \'\'Hydrochoeropsis\'\', and \'\'Neochoerus\'\' are all capybaras under that concept.<ref name="Cerdeño 2019" />',
#  '==Description==\n{{multiple image\n | image1 = Taxidermy specimen of Capybara (Hydrochoerus hydrochaeris).jpg\n | alt1 = Taxidermy specimen of a capybara\n | image2 = Capybara skeleton.jpg\n | alt2 = Skeleton of a capybara\n | footer = From left to right: Taxidermy specimen and skeleton of a capybara\n | align = left\n}}\nThe capybara has a heavy, barrel-shaped body and short head, with reddish-brown fur on the upper part of its body that turns yellowish-brown underneath. Its sweat glands can be found in the surface of the hairy portions of its skin, an unusual trait among rodents.<ref name="r4" /> The animal lacks [[Fur#Down hair|down hair]], and its [[Fur#Guard hair|guard hair]] differs little from over hair.<ref>{{Cite web|url=https://www.worldatlas.com/articles/10-delightful-facts-about-capybaras.html|title=The Cabybara – 10 Facts About the World\'s Largest Rodent|website=WorldAtlas|date=26 July 2019|language=en|access-date=2020-03-18}}</ref>',
#  'Adult capybaras grow to {{convert|106|to|134|cm|ft|abbr=on}} in length, stand {{convert|50|to|62|cm|in|abbr=on}} tall at the [[withers]], and typically weigh {{convert|35|to|66|kg|lb|abbr=on}}, with an average in the Venezuelan [[llanos]] of {{convert|48.9|kg|lb|abbr=on}}.<ref name=Arkive>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/#text=Facts Capybara] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/#text=Facts#text=Facts |date=2012-01-03 }}, Arkive</ref><ref name="Smithsonian"/><ref name="Palm Beach Zoo"/> Females are slightly heavier than males. The top recorded weights are {{convert|91|kg|lb|abbr=on}} for a wild female from Brazil and {{convert|73.5|kg|lb|abbr=on}} for a wild male from Uruguay.<ref name=r4/><ref name=r3/> Also, an 81&nbsp;kg individual was reported in São Paulo in 2001 or 2002.<ref>{{cite journal |last1=Ferraz |first1=Katia Maria Paschoaletto Micchi de Barros |last2=Bonach |first2=Kelly |last3=Verdade |first3=Luciano Martins |title=Relationship between body mass and body length in capybaras (\'\'Hydrochoerus hydrochaeris\'\') |journal=Biota Neotropica |date=2005 |volume=5 |issue=1 |pages=197–200 |doi=10.1590/S1676-06032005000100020 |doi-access=free }}</ref> The [[dental formula]] is {{DentalFormula|upper=1.0.1.3|lower=1.0.1.3}}. Capybaras have slightly [[Interdigital webbing|webbed]] feet and [[Vestigiality|vestigial]] tails.<ref name=r4/> Their hind legs are slightly longer than their forelegs; they have three toes on their rear feet and four toes on their front feet.<ref name="enchantedlearning.com">{{cite web|url=http://www.enchantedlearning.com/subjects/mammals/rodent/Capybaraprintout.shtml |title=Capybara Printout |publisher=Enchantedlearning.com |access-date=2013-05-27}}</ref> Their muzzles are blunt, with nostrils, and the eyes and ears are near the top of their heads.',
#  'Its [[karyotype]] has [[Diploid|2n]] = 66 and [[Fundamental number|FN]] = 102, meaning it has 66 chromosomes with a total of 102 arms.<ref name=msw3/><ref name=r4/>',
#  '==Ecology==\n[[File:Cattle tyrant (Machetornis rixosa) on Capybara.jpg|thumb|left|[[Cattle tyrant]] on a capybara]]',
#  'Capybaras are [[semiaquatic]] mammals<ref name="Palm Beach Zoo"/> found throughout all countries of South America except [[Chile]].<ref name="Bristol"/> They live in densely forested areas near bodies of water, such as lakes, rivers, swamps, ponds, and marshes,<ref name="Smithsonian"/> as well as flooded savannah and along rivers in the tropical rainforest. They are superb swimmers and can hold their breath underwater for up to five minutes at a time. Capybara have flourished in cattle ranches. They roam in home ranges averaging {{convert|10|ha|acre|abbr=off}} in high-density populations.<ref name=r4/>',
#  "Many escapees from captivity can also be found in similar watery habitats around the world. Sightings are fairly common in [[Florida]], although a breeding population has not yet been confirmed.<ref>{{cite web|url=http://myfwc.com/wildlifehabitats/nonnatives/mammals/capybara/|title=Nonnatives – Capybara|website=myfwc.com|access-date=2013-08-30|archive-date=2014-04-06|archive-url=https://web.archive.org/web/20140406221051/http://myfwc.com/wildlifehabitats/nonnatives/mammals/capybara/}}</ref> In 2011, one specimen was spotted on the [[Central Coast (California)|Central Coast of California]].<ref>{{cite news|url=http://www.latimes.com/news/local/la-me-0818-capybara-20110818,0,104462.story|title=A gnawing question answered: It's a capybara roaming Paso Robles|last=Mather|first=Kate|date=18 August 2011|work=[[Los Angeles Times]]|access-date=10 January 2012}}</ref> These escaped populations occur in areas where prehistoric capybaras inhabited; [[late Pleistocene]] capybaras inhabited Florida<ref>{{Cite journal|url=https://bioone.org/journals/proceedings-of-the-academy-of-natural-sciences-of-philadelphia/volume-167/issue-1/053.167.0105/A-Late-Pleistocene-capybara-Rodentia-Caviidae-Hydrochoerinae-from-near-Houston/10.1635/053.167.0105.short|doi=10.1635/053.167.0105|title=A Late Pleistocene capybara (Rodentia, Caviidae, Hydrochoerinae) from near Houston, Texas, USA, with a brief review of North American fossil capybaras|year=2020|last1=Baskin|first1=Jon|last2=Gervais|first2=P. Darrow|last3=Gervais|first3=Camille J.|journal=Proceedings of the Academy of Natural Sciences of Philadelphia|volume=167|issue=1 |page=57|bibcode=2020PANSP.167...57B |s2cid=216241471|url-access=subscription}}</ref> and ''[[Hydrochoerus hesperotiganites]]'' in [[California]] and ''[[Hydrochoerus gaylordi]]'' in [[Grenada]], and feral capybaras in North America may actually fill the ecological niche of the Pleistocene species.<ref>Erick J. Lundgren, Daniel Ramp, John Rowan, Owen Middleton, Simon D. Schowanek, Oscar Sanisidro, Scott P. Carroll, Matt Davis, Christopher J. Sandom, Jens-Christian Svenning, Arian D. Wallach, James A. Estes, 2020, ''[https://www.pnas.org/content/117/14/7871 Introduced herbivores restore Late Pleistocene ecological functions]'', PNAS, 117 (14), pp.7871-7878, [[Proceedings of the National Academy of Sciences of the United States of America]]</ref>",
#  '===Diet and predation===\n[[File:Capybara Eating Hay 11 11 2018.jpg|thumb|A capybara eating hay at [[Franklin Park Zoo]], Boston, Massachusetts]]',
#  'Capybaras are [[herbivore]]s, grazing mainly on grasses and [[aquatic plants]],<ref name="Smithsonian"/><ref name="RevBiolTrop"/> as well as fruit and tree bark.<ref name="Palm Beach Zoo"/> They are very selective feeders<ref name="Quintana 1998"/> and feed on the leaves of one species and disregard other species surrounding it. They eat a greater variety of plants during the dry season, as fewer plants are available. While they eat grass during the wet season, they have to switch to more abundant reeds during the dry season.<ref name="Barreto 1998"/> Plants that capybaras eat during the summer lose their nutritional value in the winter, so they are not consumed at that time.<ref name="Quintana 1998"/> The capybara\'s jaw hinge is not perpendicular, so they chew food by grinding back-and-forth rather than side-to-side.<ref name="SFZoo"/> Capybaras are [[coprophagous|autocoprophagous]],<ref name="taronga-zoo"/> meaning they eat their own feces as a source of bacterial [[gut flora]], to help digest the [[cellulose]] in the grass that forms their normal diet, and to extract the maximum protein and vitamins from their food. They also regurgitate food to masticate again, similar to cud-chewing by cattle.<ref name="taronga-zoo">{{cite web |title=Meet Taronga\'s Capybaras |url=https://taronga.org.au/sydney-zoo/must-see/capybaras |website=Taronga Zoo |access-date=29 December 2021 |ref=taronga-zoo}}</ref><ref name="Lord-Rexford 1994"/> Like other rodents, a capybara\'s front teeth grow continually to compensate for the constant wear from eating grasses;<ref name="Bristol"/> their cheek teeth also grow continuously.<ref name="SFZoo"/> ',
#  'Like its relative the guinea pig, the capybara does not have the capacity to synthesize [[vitamin C]], and capybaras not supplemented with vitamin C in captivity have been reported to develop [[Periodontal disease|gum disease]] as a sign of [[scurvy]].<ref name=r2/>',
#  'The maximum lifespan of the capybara is 8 to 10 years,<ref name=r6/> but in the wild capybaras usually do not live longer than four years because of predation from South American [[big cats]] such as [[jaguar]]s and [[cougar]]s and from non-mammalian predators such as [[caiman]]s, [[Eunectes murinus|green anaconda]]s and [[piranha]]s.<ref name="Bristol"/><ref name="SoundsandColours"/>',
#  '==Social organization==\n[[File:Capybara (Hydrochoerus hydrochaeris) alpha male.JPG|thumb|right|Capybaras have a scent gland on their noses.]]',
#  'Capybaras are known to be [[gregarious]]. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles.<ref name="Alho 1987"/> Capybara groups can consist of as many as 50 or 100 individuals during the dry season<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.<ref name="Macdonald 1981"/> They can make dog-like barks<ref name="Lord-Rexford 1994"/> when threatened or when females are herding young.<ref name="Murphey 1985"/>',
#  'Capybaras have two types of [[scent gland]]s: a morrillo, located on the snout, and [[anal gland]]s. Both sexes have these glands, but males have much larger morrillos and use their anal glands more frequently. The anal glands of males are also lined with detachable hairs. A crystalline form of scent secretion is coated on these hairs and is released when in contact with objects such as plants. These hairs have a longer-lasting scent mark and are tasted by other capybaras. Capybaras scent-mark by rubbing their morrillos on objects, or by walking over scrub and marking it with their anal glands. Capybaras can spread their scent farther by urinating; however, females usually mark without urinating and scent-mark less frequently than males overall. Females mark more often during the wet season when they are in [[estrus]]. In addition to objects, males also scent-mark females.<ref name="Macdonald 1984"/>',
#  '===Reproduction===\n[[File:Young capybaras.jpg|thumb|left|Mother with typical litter of about four pups]]\nWhen in [[estrus]], the female\'s scent changes subtly and nearby males begin pursuit.<ref name="Herrera 1993">{{cite journal|doi=10.1093/beheco/4.2.114|title= Aggression, dominance, and mating success among capybara males (\'\'Hydrochaeris hypdrochaeris\'\')|year=1993|last1=Herrera|first1=Emilio A.|last2=MacDonald|first2=David W.|journal=[[Behavioral Ecology (journal)|Behavioral Ecology]]|volume=4|issue=2|page=114}}</ref> In addition, a female alerts males she is in estrus by whistling through her nose.<ref name="Lord-Rexford 1994"/> During mating, the female has the advantage and mating choice. Capybaras mate only in water, and if a female does not want to mate with a certain male, she either submerges or leaves the water.<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> Dominant males are highly protective of the females, but they usually cannot prevent some of the subordinates from copulating. The larger the group, the harder it is for the male to watch all the females. Dominant males secure significantly more matings than each subordinate, but subordinate males, as a class, are responsible for more matings than each dominant male.<ref name="Herrera 1993"/> The lifespan of the capybara\'s sperm is longer than that of other rodents.<ref name=r1/> Capybara [[gestation]] is 130–150 days, and produces a litter of four young on average, but may produce between one and eight in a single litter.<ref name=r4/> Birth is on land and the female rejoins the group within a few hours of delivering the newborn capybaras, which join the group as soon as they are mobile. Within a week, the young can eat grass, but continue to suckle—from any female in the group—until weaned around 16 weeks. The young form a group within the main group.<ref name="Bristol"/> [[Alloparenting]] has been observed in this species.<ref name="Macdonald 1981"/> Breeding peaks between April and May in Venezuela and between October and November in [[Mato Grosso]], Brazil.<ref name=r4/>',
#  '===Activities===\nThough quite agile on land, capybaras are equally at home in the water. They are excellent swimmers, and can remain completely submerged for up to five minutes,<ref name="Smithsonian"/> an ability they use to evade predators. Capybaras can sleep in water, keeping only their noses out. As temperatures increase during the day, they wallow in water and then graze during the late afternoon and early evening.<ref name=r4/> They also spend time wallowing in mud.<ref name="enchantedlearning.com"/> They rest around midnight and then continue to graze before dawn.<ref name="r4" />',
#  '===Communication===\nCapybaras communicate using barks, chirps, whistles, huffs, and purrs.<ref>{{cite web | url=https://zoo.sandiegozoo.org/animals/capybara | title=Capybara }}</ref>',
#  '[[File:Capybara Ueno Zoo 2009.ogv|thumb|A capybara in captivity, 2009]]',
#  '==Conservation and human interaction==\nCapybaras are not considered a threatened species;<ref name="iucn status 19 November 2021" /> their population is stable throughout most of their South American range, though in some areas hunting has reduced their numbers.<ref name="Smithsonian"/><ref name="Bristol"/> Capybaras are hunted for their meat and pelts in some areas,<ref name="inRich" /> and otherwise killed by humans who see their grazing as competition for livestock. In some areas, they are farmed, which has the effect of ensuring the wetland habitats are protected. Their survival is aided by their ability to breed rapidly.<ref name="Bristol" />',
#  'Capybaras have adapted well to urbanization in South America. They can be found in many areas in zoos and parks,<ref name="SFZoo" /> and may live for 12 years in captivity, more than double their wild lifespan.<ref name="Bristol" /> Capybaras are docile and usually allow humans to pet and hand-feed them, but physical contact is normally discouraged, as their [[tick]]s can be [[vector (epidemiology)|vectors]] to [[Rocky Mountain spotted fever]].<ref>{{cite web|url=http://drauziovarella.com.br/audios-videos/estacao-medicina/febre-maculosa/ |title=Febre maculosa: "Os médicos no Brasil não conhecem a doença|date=12 April 2011|trans-title= Rocky Mountain spotted fever: Brazilian doctors unaware of the disease |language=pt |publisher=drauziovarella.com.br |access-date=2015-08-13}}</ref> The [[European Association of Zoos and Aquaria]] asked [[Drusillas Park]] in [[Alfriston]], [[Sussex]], England, to keep the [[studbook]] for capybaras, to monitor captive populations in Europe. The studbook includes information about all births, deaths and movements of capybaras, as well as how they are related.<ref>{{cite web|url=http://www.drusillas.co.uk/conservation-1 |title=Conservation at Drusillas Park |publisher=Drusillas.co.uk |access-date=2013-05-27}}</ref>',
#  'Capybaras are farmed for meat and skins in South America.<ref name="SDzoo"/> The meat is considered unsuitable to eat in some areas, while in other areas it is considered an important source of protein.<ref name=r4/> In parts of South America, especially in Venezuela, capybara meat is popular during [[Lent]] and [[Holy Week]] as the Catholic Church (according to a legend) previously issued special dispensation to allow it to be eaten while other meats are [[Fasting and abstinence in the Catholic Church|generally forbidden]].<ref name="NYSun"/><ref name="NYTimes2007">{{Cite news |last=Romero |first=Simon |date=2007-03-21 |title=In Venezuela, Rodents Can Be a Delicacy |url=https://www.nytimes.com/2007/03/21/world/americas/21rodent.html |archive-url=https://archive.today/20131014211839/http://www.nytimes.com/2007/03/21/world/americas/21rodent.html?_r=0 |archive-date=14 Oct 2013 |access-date=2021-04-27 |work=The New York Times |language=en-US |issn=0362-4331 |quote=Legend has it that eating capybara, known here as chigüire (pronounced chee-GWEE-reh), got a boost in the 18th century when the local clergy asked the Vatican to give capybara the status of fish. (...) It remains more popular in Venezuela\'s rural interior than in the capital.}}</ref> There is widespread perception in Venezuela that consumption of capybaras is exclusive to rural people.<ref name="NYTimes2007"/>',
#  'In August 2021, Argentine and international media reported that capybaras had been disturbing residents of [[Nordelta]], an affluent gated community north of [[Buenos Aires]] built atop the local capybara\'s preexisting wetland habitat. This inspired social media users to jokingly adopt the capybara as a symbol of [[class struggle]] and [[communism]].<ref name="TheGuardian_20210822">{{cite web|title=Attack of the giant rodents or class war? Argentina\'s rich riled by new neighbors|newspaper=[[The Guardian]] |date=22 August 2021 |url=https://www.theguardian.com/world/2021/aug/22/argentina-capybaras-giant-rodents-gated-community |last=Goñi |first=Uki}}</ref> Brazilian Lyme-like [[borreliosis]] likely involves capybaras as reservoirs and \'\'[[Amblyomma]]\'\' and \'\'[[Rhipicephalus]]\'\' ticks as vectors.<ref>{{cite journal |last1=Basile |first1=Roberta Carvalho |last2=Yoshinari |first2=Natalino Hajime |last3=Mantovani |first3=Elenice |last4=Bonoldi |first4=Virgínia Nazário |last5=Macoris |first5=Delphim da Graça |last6=Queiroz-Neto |first6=Antonio de |title=Brazilian borreliosis with special emphasis on humans and horses |journal=Brazilian Journal of Microbiology |date=4 October 2016 |volume=48 |issue=1 |pages=167–172 |doi=10.1016/j.bjm.2016.09.005 |pmid=27769883 |pmc=5220628 }}</ref>',
#  'A [[Animal cafe#Capybara café|Capybara café]] in [[St. Augustine, Florida|St. Augustine]], [[Florida]]  allows visitors to interact with and give head scratches to the rodents.<ref>{{cite news|title=Giant rodents cuddle with visitors at the Capybara Cafe in Florida|url=https://apnews.com/article/florida-capybara-cafe-st-augustine-54ce3807f084e9de61f72a79c6633e10|newspaper=Associated Press News|date=April 12, 2025}}</ref>',
#  '== In popular culture ==\n[[Izu Shaboten Zoo]] and other zoos in Japan have created [[onsen|hot spring baths]] for capybaras.<ref name="reuters">{{cite web|url=https://www.reuters.com/article/us-olympics-2020-capybara-idCAKBN1ZY0FY|title=Olympics and Year of the Rat give starring role to Japan\'s capybaras|website=[[Reuters]]|first=Sakura|last=Murakami|date=4 February 2020|access-date=23 October 2021}}</ref> Video clips of the bathing capybaras have gained millions of views.<ref name="reuters"/> The capybaras have influenced an [[anime]] character named \'\'Kapibara-san\'\', and a series of merchandise such as [[plush toy]]s.<ref>{{cite web|url=https://qz.com/986398/how-the-capybara-the-worlds-largest-rodent-became-a-superstar-in-japan/|title=How the world\'s largest rodent became a superstar in Japan|website=[[Quartz (publication)|Quartz]]|first=Isabella|last=Steger|date=19 May 2017|access-date=23 October 2021}}</ref> ',
#  'Capybaras have long been a figure in [[Internet meme|meme culture]],<ref>{{cite news |last1=Diaz |first1=Ana |title=Capybaras are taking over TikTok and we\'re better for it |url=https://www.polygon.com/23620358/capybara-tiktok-meme-audio-trend |access-date=28 February 2025 |work=Polygon |date=March 2, 2023}}</ref> particularly in the 2020s.<ref name="euronewsmeme">{{cite news |last1=Mouriquand |first1=David |title=Why are capybaras systematically taking over social media? |url=https://www.euronews.com/culture/2023/04/12/why-are-capybaras-systematically-taking-over-social-media |access-date=24 February 2025 |work=Euro News |date=December 4, 2023}}</ref> In 2022, [[Peronists]] in Argentina presented them as figures of class struggle after the disturbances in Nordelta.<ref name=TheGuardian_20210822 /> Common meme formats pair capybaras with the song "[[After Party (song)|After Party]]" by [[Don Toliver]].<ref name="euronewsmeme"/><ref>{{Cite web |last=Lopez |first=Sophia |date=2022-08-01 |title=Capybaras are taking over the internet |url=https://thegauntlet.ca/2022/08/01/capybaras-are-taking-over-the-internet/ |access-date=2022-09-02 |website=The Gauntlet |language=en-US}}</ref>',
#  "==See also==\n{{Portal|Mammals|South America}}\n* ''[[Josephoartigasia monesi]]'', an extinct species identified as the largest known rodent ever\n* [[Kurloff cell]], a type of cell found in capybaras and guinea pigs\n* ''[[Capybara Walking]]'', a historical animal locomotion film by [[Eadweard Muybridge]]",
#  '==Notes==\n<references group="note" />\n{{notelist}}',
#  '==References==\n{{Reflist|30em|refs=\n<ref name="Bristol">[http://www.bristolzoo.org.uk/learning/animals/mammals/capybara Bristol Zoo Gardens (UK) \'\'Capybara\'\'] {{webarchive|url=https://web.archive.org/web/20070918183854/http://www.bristolzoo.org.uk/learning/animals/mammals/capybara |date=2007-09-18 }}. Bristolzoo.org.uk. Retrieved on 2011-12-07.</ref>\n<ref name="Barreto 1998">{{cite journal |title=Foraging patterns of capybaras in a seasonally flooded savanna of Venezuela| jstor=2559868|doi=10.1017/S0266467498000078 |year=1998 |last1=Barreto |first1=Guillermo R. |last2=Herrera |first2=Emilio A. |journal=Journal of Tropical Ecology |volume=14 | issue=1| pages=87–98| s2cid=84982123}}</ref>\n<ref name="Quintana 1998">{{cite journal |last1=Quintana |first1=R.D. |last2=Monge |first2=S. |last3=Malvárez |first3=A.I. |title=Feeding patterns of capybara \'\'Hydrochaeris hydrochaeris\'\' (Rodentia, Hydrochaeridae) and cattle in the non-insular area of the Lower Delta of the Paraná River, Argentina |journal=Mammalia |date=1998 |volume=62 |issue=1 |pages=37–52 |doi=10.1515/mamm.1998.62.1.37 |s2cid=83976640 }}</ref>\n<ref name=r6>Burton M and Burton R. (2002) \'\'The International Wildlife Encyclopedia\'\'. Marshall Cavendish, {{ISBN|0-7614-7269-X}}, p. 384</ref>\n<ref name="SoundsandColours">[http://soundsandcolours.com/subjects/south-american-nature/capybara-the-master-of-the-grasses-pest-or-prey-3937/ Capybara, the master of the grasses: pest or prey]  Sounds and Colours. Retrieved on 23 January 2011.</ref>\n<ref name="SFZoo">[https://web.archive.org/web/20070614005832/http://www.sfzoo.org/cgi-bin/animals.py?ID=90 Capybara. \'\'Hydrochaeris hydrochaeris\'\']. San Francisco Zoo</ref>\n<ref name="SDzoo">{{cite web  | date = October 2008  | publisher = San Diego Zoo  | title = Capybara, \'\'Hydrochoerus hydrochaeris\'\'  | url = http://library.sandiegozoo.org/factsheets/capybara/capybara.htm  | access-date = 22 June 2011  | archive-url = https://web.archive.org/web/20110930051431/http://library.sandiegozoo.org/factsheets/capybara/capybara.htm  | archive-date = 30 September 2011  }}</ref>\n<ref name="Alho 1987">{{cite journal |last1=Alho |first1=Cleber J.R. |last2=Rondon |first2=Nelson L. |title=Habitats, population densities, and social structure of capybaras (\'\'Hydrochaeris Hydrochaeris\'\', Rodentia) in the Pantanal, Brazil |journal=[[Revista Brasileira de Zoologia]] |date=1987 |volume=4 |issue=2 |pages=139–149 |doi=10.1590/s0101-81751987000200006 |doi-access=free }}</ref>\n<ref name="Lord-Rexford 1994">{{cite journal |last1=Lord |first1=Rexford D. |title=A descriptive account of capybara behaviour |journal=Studies on Neotropical Fauna and Environment |date=March 1994 |volume=29 |issue=1 |pages=11–22 |doi=10.1080/01650529409360912 |bibcode=1994SNFE...29...11L }}</ref>\n<ref name="Macdonald 1981">{{cite journal |last1=Macdonald |first1=D. W. |title=Dwindling resources and the social behaviour of Capybaras, (\'\'Hydrochoerus hydrochaeris\'\') (Mammalia) |journal=Journal of Zoology |date=July 1981 |volume=194 |issue=3 |pages=371–391 |doi=10.1111/j.1469-7998.1981.tb04588.x }}</ref>\n<ref name="Murphey 1985">{{cite journal |last1=Murphey |first1=Robert M. |last2=Mariano |first2=Jorge S. |last3=Moura Duarte |first3=Francisco A. |title=Behavioral observations in a capybara colony (\'\'Hydrochoerus hydrochaeris\'\') |journal=Applied Animal Behaviour Science |date=May 1985 |volume=14 |issue=1 |pages=89–98 |doi=10.1016/0168-1591(85)90040-1 }}</ref>\n<ref name=r1>{{cite journal |last1=Paula |first1=T.A.R. |last2=Chiarini-Garcia |first2=H. |last3=França |first3=L.R. |title=Seminiferous epithelium cycle and its duration in capybaras (Hydrochoerus hydrochaeris) |journal=Tissue and Cell |date=June 1999 |volume=31 |issue=3 |pages=327–334 |doi=10.1054/tice.1999.0039 |pmid=10481304 }}</ref>\n<ref name=r2>{{cite journal |last1=Cueto |first1=Gerardo Ruben |last2=Allekotte |first2=Roman |last3=Kravetz |first3=Fernando Osvaldo |title=Scurvy in capyb ...
#  "==External links==\n{{EB1911 poster|Capybara}}\n{{Wiktionary|capybara}}\n* {{cite web|title=Companionable Capybaras (18 Photos)|author=Alan Taylor|date=29 November 2018|website=The Atlantic|url=https://www.theatlantic.com/photo/2018/11/photos-companionable-capybaras/576991/}}\n* [https://animaldiversity.org/site/accounts/information/Hydrochoerus_hydrochaeris.html Animal Diversity Web ''Hydrochoerus hydrochaeris'']\n* [https://capybarafacts.com Capybara information]",
#  '{{Caviidae nav}}\n{{Taxonbar|from=Q131538}}',
#  '[[Category:Mammals described in 1766]]\n[[Category:Cavies]]\n[[Category:Herbivorous mammals]]\n[[Category:Mammals of Argentina]]\n[[Category:Mammals of Bolivia]]\n[[Category:Rodents of Brazil]]\n[[Category:Mammals of Colombia]]\n[[Category:Mammals of Ecuador]]\n[[Category:Mammals of French Guiana]]\n[[Category:Mammals of Guyana]]\n[[Category:Mammals of Paraguay]]\n[[Category:Mammals of Peru]]\n[[Category:Mammals of Uruguay]]\n[[Category:Mammals of Venezuela]]\n[[Category:Articles containing video clips]]\n[[Category:Semiaquatic mammals]]\n[[Category:Animal taxa named by Carl Linnaeus]]\n[[Category:2020s in Internet culture]]\n[[Category:Internet memes introduced in the 2020s]]']

# %%
# import requests
# from requests.exceptions import RequestException, HTTPError, Timeout

# class WikiSearch:
#     """
#     A lightweight wrapper for interacting with the Wikipedia API.

#     This class allows you to search for Wikipedia articles based on a keyword,
#     store the results, and fetch raw page contents for each matched title.
#     """

#     # def __init__(self):
#     #     """
#     #     Initialize a WikiSearch instance.

#     #     Attributes:
#     #         keyword_list (list[str]): A list of Wikipedia article titles retrieved from searches.
#     #     """
#     #     # self.keyword_list = []
#         # pass

#     def get_keywords(self, keyword: str) -> List[str]:
#         """
#         Extract related Wikipedia article titles for a given keyword.

#         This method searches Wikipedia using the input keyword, collects
#         relevant article titles, and formats them for subsequent retrieval.

#         Args:
#             keyword (str): The search keyword or phrase.

#         Returns:
#             list[str]: A list of related article titles, formatted with '+' 
#                     instead of spaces. Each item is guaranteed to be a string.
                    
#         Type Schema for Function Calling:
#             type: object
#             properties:
#                 keyword:
#                     type: string
#                     description: The main search keyword to find related Wikipedia articles.
#             required: ["keyword"]
#         """
#         if not keyword or not keyword.strip():
#             raise ValueError("Keyword must be a non-empty string.")

#         url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch={keyword}"

#         # try:
#         response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
#         response.raise_for_status()
#         # except Timeout:
#         #     print(f"⏳ Request timed out for keyword: '{keyword}'. Skipping...")
#         #     return []
#         # except HTTPError as e:
#         #     print(f"❌ HTTP error for keyword '{keyword}': {e}")
#         #     return []
#         # except RequestException as e:
#         #     print(f"⚠️ Network error during search for '{keyword}': {e}")
#         #     return []

#         # try:
#         json_response = response.json()
#         search_results = json_response.get("query", {}).get("search", [])
#         keyword_list = []
#         # except ValueError:
#         #     print("⚠️ Failed to parse JSON response from Wikipedia.")
#         #     return []

#         # if not search_results:
#         #     print(f"ℹ️ No search results found for keyword: '{keyword}'.")
#         #     return []

#         for search in search_results:
#             title = search.get("title", "").strip()
#             if title:
#                 search_keyword = "+".join(title.split(" "))
#                 keyword_list.append(search_keyword)

#         return keyword_list

#     def get_keyword_page(self, keyword_list: List[str]) -> List[Dict]:
#         """
#             Retrieve raw Wikipedia page content for a list of article titles.

#             For each title in the provided `keyword_list`, this method fetches the
#             corresponding raw wikitext content using the Wikipedia API (`action=raw`)
#             and structures the results for indexing or downstream processing.

#             Args:
#                 keyword_list (list[str]): A list of Wikipedia article titles to fetch.

#             Returns:
#                 list[dict]: A list of dictionaries, each containing:
#                     - 'title' (str): The Wikipedia page title.
#                     - 'content' (str): The raw wikitext content of the page.

#             Type Schema for Function Calling:
#                 type: object
#                 properties:
#                     keyword_list:
#                         type: array
#                         items:
#                             type: string
#                         description: List of Wikipedia article titles to fetch.
#                 required: ["keyword_list"]
#             """
#         result = []
#         for search_keyword in keyword_list:
#             # try:
#             url = f"https://en.wikipedia.org/w/index.php?title={search_keyword}&action=raw"
#             response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
#             response.raise_for_status()
            
#             content = response.content.decode("utf-8")
#             result.append({"title": search_keyword, "content": content})

#             # except Timeout:
#             #     print(f"⏳ Timeout while fetching page: {search_keyword}. Skipping...")
#             # except HTTPError as e:
#             #     print(f"❌ HTTP error for page '{search_keyword}': {e}")
#             # except RequestException as e:
#             #     print(f"⚠️ Network error while fetching '{search_keyword}': {e}")
#             # except UnicodeDecodeError:
#             #     print(f"⚠️ Could not decode content for '{search_keyword}'. Skipping...")

#         if not result:
#             print("⚠️ No valid pages were fetched.")
        
#         return result

# %%
import requests
from requests.exceptions import RequestException, HTTPError, Timeout
from typing import List, Dict


class WikiSearch:
    """
    A lightweight wrapper for interacting with the Wikipedia API.

    This class allows you to search for Wikipedia articles based on a keyword,
    store the results, and fetch raw page contents for each matched title.
    """

    # def __init__(self):
    #     """
    #     Initialize a WikiSearch instance.

    #     Attributes:
    #         keyword_list (list[str]): A list of Wikipedia article titles retrieved from searches.
    #     """
    #     # self.keyword_list = []
        # pass

    def get_keywords(self, keyword: str) -> List[str]:
        """
        Extract related Wikipedia article titles for a given keyword.

        This method searches Wikipedia using the input keyword, collects
        relevant article titles, and formats them for subsequent retrieval.

        Args:
            keyword (str): The search keyword or phrase.

        Returns:
            list[str]: A list of related article titles, formatted with '+' 
                    instead of spaces. Each item is guaranteed to be a string.
                    
        Type Schema for Function Calling:
            type: object
            properties:
                keyword:
                    type: string
                    description: The main search keyword to find related Wikipedia articles.
            required: ["keyword"]
        """
        if not keyword or not keyword.strip():
            raise ValueError("Keyword must be a non-empty string.")

        url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch={keyword}"

        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
        response.raise_for_status()

        json_response = response.json()
        search_results = json_response.get("query", {}).get("search", [])
        keyword_list = []


        for search in search_results:
            title = search.get("title", "").strip()
            if title:
                search_keyword = "+".join(title.split(" "))
                keyword_list.append(search_keyword)

        return keyword_list

    def get_keyword_page(self, search_keyword: str) -> List[Dict]:
        """
        Fetch the raw Wikipedia page content for a single keyword.

        Args:
            search_keyword (str): One Wikipedia article title.

        Returns:
            list[dict]: [{'title': search_keyword, 'content': page_content, 'url': search_url}]
        """
        try:
            url = f"https://en.wikipedia.org/w/index.php?title={search_keyword}&action=raw"
            response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
            response.raise_for_status()
            
            content = response.content.decode("utf-8")
        except (Timeout, HTTPError, RequestException, UnicodeDecodeError) as e:
            print(f"⚠️ Error fetching page '{search_keyword}': {e}")
            content = ""
            

        if not content:
            print(f"⚠️ No valid pages were fetched. keyword: {search_keyword}")
        
        return [{"title": search_keyword, "content": content, "url": url}]

# %%
wiki_search = WikiSearch()

keyword_list = wiki_search.get_keywords(keyword='capybara')
keyword_list
# Out:
# ['Capybara',
#  'Capybara+(disambiguation)',
#  'Lesser+capybara',
#  'Capybara+Games',
#  'Caviidae',
#  'Hydrochoerus',
#  'Flow+(2024+film)',
#  'Yuzu+bath',
#  'Capybara+(software)',
#  'Kerodon']

# %%
data = wiki_search.get_keyword_page(search_keyword='Capybara')

# %%
data
# Out:
# [{'title': 'Capybara',
#   'content': '{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name="iucn status 19 November 2021">{{cite iucn |author=Reid, F. |date=2016 |title=\'\'Hydrochoerus hydrochaeris\'\' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petrópolis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petrópolis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = \'\'Sus hydrochaeris\'\' {{small|Linnaeus,&nbsp;1766}}\n}}\n\nThe \'\'\'capybara\'\'\'{{efn | Also referred as \'\'\'capivara\'\'\' (in Brazil), \'\'\'capiguara\'\'\' (in Bolivia), \'\'\'chigüire\'\'\', \'\'\'chigüiro\'\'\', or \'\'\'fercho\'\'\' (in Colombia and Venezuela), \'\'\'carpincho\'\'\' (in Argentina, Paraguay and Uruguay) and \'\'\'ronsoco\'\'\' (in Peru).}} or \'\'\'greater capybara\'\'\' (\'\'\'\'\'Hydrochoerus hydrochaeris\'\'\'\'\') is the largest living rodent,<ref>{{Cite web | author= Basic Biology | date= 2015 | title= Rodents | url= https://basicbiology.net/animal/mammals/rodents}}</ref> native to [[South America]]. It is a member of the genus \'\'[[Hydrochoerus]]\'\'. Its close relatives include\n[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. The capybara is hunted for its meat and hide and also for grease from its thick fatty skin.<ref>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (\'\'Hydrochoerus hydrochaeris\'\')] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ |date=2012-01-03 }}. ARKive.org</ref>\n\n==Etymology==\nIts common name is derived from [[Tupi language|Tupi]] {{lang|tpn|ka\'apiûara}}, a complex agglutination of {{lang|tpn|kaá}} (leaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent nouns), meaning "one who eats slender leaves", or "grass-eater".<ref>Ferreira, A. B. H. (1986) \'\'[[Novo Dicionário da Língua Portuguesa]]\'\', 2nd ed., Rio de Janeiro: Nova Fronteira, p.344</ref> The [[genus name]], \'\'hydrochoerus\'\', comes from [[Ancient Greek|Greek]] {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the species name, \'\'hydrochaeris\'\', comes from Greek {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χαίρω}} (\'\'{{lang|grc-Latn|chairo}}\'\' "feel happy, enjoy").<ref name=msw3>{{MSW3 Woods|id=13400218|page=1556}}</ref><ref name="inDarwin">{{Cite book | last=Darwin | first=Charles R. | author-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Ships Adventure and Beagle between the years 1826 and 1836, describing their examination of the southern shores of South America, and the Beagle\'s circumnavigation of the globe. Journal and remarks. 1832–1836. | title-link =The Voyage of the Beagle| place =London | publisher =[[Henry Colburn]] | page=619}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'\' (the water-hog), is here also common."\n* See it also in [http://darwin-online.org.uk/content/frameset?itemID=F10.3&viewtype=side&pageseq=1 The C ...
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}]

# %%
from typing import Any, Dict, List

class SearchTools:

    def __init__(self, index):
        self.index = index

    def search(self, query: str, num_results: int = 5) -> List[Dict[str, Any]]:
        """
        Search for documents in the index related to the given query.

        This method retrieves the most relevant documents based on the query
        text, ranking results according to field importance.

        Args:
            query (str): The search query string.
            num_results (int, optional): Maximum number of search results to return. Defaults to 5.

        Returns:
            List[Dict[str, Any]]:
                A list of dictionaries, each representing a search result with the following keys:
                - 'title' (str): The document title.
                - 'content' (str): A relevant content snippet or text chunk.
                - 'url' (str or None): The source URL, if available.

        Example:
            >>> tools.search("Capybara behavior")
            [
                {
                    "title": "Capybara Social Behavior",
                    "content": "Capybaras are highly social animals that live in groups...",
                    "url": "https://example.com/capybara-behavior"
                },
                {
                    "title": "Capybara Habitat and Lifestyle",
                    "content": "They spend much of their time near water and are excellent swimmers...",
                    "url": "https://example.com/capybara-habitat"
                }
            ]
        """
        boost = {"title": 2.0, "summary": 1.0, "details": 0.5}
        
        results = self.index.search(
            query=query,
            boost_dict=boost,
            num_results=num_results,
        )
        return results

    def _chunk_with_word_window(self, data, chunk_size=200, overlap=50):
        """
        Split a single record into overlapping word-based chunks.
        
        Args:
            data (dict): {'title': str, 'content': str}
            chunk_size (int): Number of words per chunk
            overlap (int): Overlap between chunks (in words)
        
        Returns:
            list[dict]: [{'title': ..., 'content': ...}, ...]
        """
        title = data["title"]
        words = data["content"].strip().split(" ")
        chunks = []
        
        start = 0
        total_words = len(words)
        
        while start < total_words:
            end = start + chunk_size
            chunk_words = words[start:end]
            chunk_text = " ".join(chunk_words)
            
            chunks.append({
                "title": title,
                "content": chunk_text
            })
            
            start += chunk_size - overlap  # slide window forward
        
        return chunks
    
    def _chunk_with_sliding_window(self, data, chunk_size=500, overlap=100):
        """
        Split a single text record into overlapping chunks.

        This method divides the 'content' field of a record into chunks of
        specified size with overlapping text regions to preserve context.
        The record may optionally contain a 'url' field.

        Args:
            data (dict): A record containing:
                - 'title' (str): Title of the text.
                - 'content' (str): Main text content.
                - 'url' (str, optional): Source URL of the text.
            chunk_size (int): Number of characters per chunk. Defaults to 500.
            overlap (int): Number of overlapping characters between chunks. Defaults to 100.

        Returns:
            list[dict]: A list of chunk dictionaries with keys:
                - 'title' (str)
                - 'content' (str)
                - 'url' (str or None)
        """
        title = data["title"]
        content = data["content"].strip()
        url = data["url"]
        chunks = []

        start = 0
        text_length = len(content)

        while start < text_length:
            end = start + chunk_size
            chunk_text = content[start:end]
            
            chunks.append({
                "title": title,
                "content": chunk_text,
                "url": url
            })
            start += chunk_size - overlap

        return chunks

    def add_entry(self, data, chunk_size=500, overlap=100):

        """
        Add text entries into the index after chunking them into overlapping windows.

        This method takes a list of text records (each containing at least a 'title'
        and 'content', and optionally a 'url'), splits each record into smaller
        chunks using a sliding window, and appends the resulting chunks to the
        internal index.

        Args:
            data (list[dict]): A list of records, each with keys:
                - 'title' (str): The title of the document.
                - 'content' (str): The full text content.
                - 'url' (str, optional): The document’s source URL.
            chunk_size (int, optional): Number of characters per chunk. Defaults to 500.
            overlap (int, optional): Overlapping characters between chunks for context continuity. Defaults to 100.

        Returns:
            list[dict]: A flattened list of all generated text chunks.
                Each element has the structure:
                {
                    'title': str,
                    'content': str,
                    'url': str or None
                }
        """
        all_chunks = []

        for record in data:
            chunks = self._chunk_with_sliding_window(record, chunk_size, overlap)
            
            
            for chunk in chunks:
                self.index.append(chunk)
            all_chunks.extend(chunks)
        
        return all_chunks

# %%
from minsearch import Index

from minsearch import AppendableIndex

index = AppendableIndex(
    text_fields=["title", "content"],
    keyword_fields=["title"]
)

search_tool = SearchTools(index)

# %%
search_tool.add_entry(data)
# Out:
# [{'title': 'Capybara',
#   'content': '{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name="iucn status 19 November 2021">{{cite iucn |author=Reid, F. |date=2016 |title=\'\'Hydrochoerus hydrochaeris\'\' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hy',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "UCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petrópolis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petrópolis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = ''Sus hydroc",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "p         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = ''Sus hydrochaeris'' {{small|Linnaeus,&nbsp;1766}}\n}}\n\nThe '''capybara'''{{efn | Also referred as '''capivara''' (in Brazil), '''capiguara''' (in Bolivia), '''chigüire''', '''chigüiro''', or '''fercho''' (in Colombia and Venezuela), '''carpincho''' (in Argentina, Paraguay and Uruguay) and '''ronsoco''' (in Peru).}} or '''greater capybara''' ('''''Hydrochoerus hydrochaeris''''') is the largest living rodent,<r",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ").}} or '''greater capybara''' ('''''Hydrochoerus hydrochaeris''''') is the largest living rodent,<ref>{{Cite web | author= Basic Biology | date= 2015 | title= Rodents | url= https://basicbiology.net/animal/mammals/rodents}}</ref> native to [[South America]]. It is a member of the genus ''[[Hydrochoerus]]''. Its close relatives include\n[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabi",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "ore distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. The capybara is hunted for its meat and hide and also for grease from its thick fatty skin.<ref>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (''Hydrochoerus hydrochaeris''",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "f>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (''Hydrochoerus hydrochaeris'')] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ |date=2012-01-03 }}. ARKive.org</ref>\n\n==Etymology==\nIts common name is derived from [[Tupi language|Tupi]] {{lang|tpn|ka'apiûara}}, a complex agglutination of {{lang|tpn|kaá}} (leaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent noun",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'eaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent nouns), meaning "one who eats slender leaves", or "grass-eater".<ref>Ferreira, A. B. H. (1986) \'\'[[Novo Dicionário da Língua Portuguesa]]\'\', 2nd ed., Rio de Janeiro: Nova Fronteira, p.344</ref> The [[genus name]], \'\'hydrochoerus\'\', comes from [[Ancient Greek|Greek]] {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the specie',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the species name, \'\'hydrochaeris\'\', comes from Greek {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χαίρω}} (\'\'{{lang|grc-Latn|chairo}}\'\' "feel happy, enjoy").<ref name=msw3>{{MSW3 Woods|id=13400218|page=1556}}</ref><ref name="inDarwin">{{Cite book | last=Darwin | first=Charles R. | author-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Shi',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'thor-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Ships Adventure and Beagle between the years 1826 and 1836, describing their examination of the southern shores of South America, and the Beagle\'s circumnavigation of the globe. Journal and remarks. 1832–1836. | title-link =The Voyage of the Beagle| place =London | publisher =[[Henry Colburn]] | page=619}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '19}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'\' (the water-hog), is here also common."\n* See it also in [http://darwin-online.org.uk/content/frameset?itemID=F10.3&viewtype=side&pageseq=1 The Complete Work of Charles Darwin Online]</ref>\n\n==Classification and phylogeny==\nThe capybara and the [[lesser capybara]] both belong to the subfamily [[Hydrochoerinae]] along with the [[Kerodon|rock cavies]]. The living capybaras and their extinct relativ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'rochoerinae]] along with the [[Kerodon|rock cavies]]. The living capybaras and their extinct relatives were previously classified in their own family Hydrochoeridae.<ref name=r4/> Since 2002, molecular phylogenetic studies have recognized a close relationship between \'\'Hydrochoerus\'\' and \'\'[[Kerodon]]\'\', the rock cavies,<ref name="Rowe 2002"/> supporting placement of both genera in a subfamily of [[Caviidae]].<ref name=msw3/>\n\nPaleontological classifications previously used Hydrochoeridae for al',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '[[Caviidae]].<ref name=msw3/>\n\nPaleontological classifications previously used Hydrochoeridae for all capybaras, while using Hydrochoerinae for the living genus and its closest fossil relatives, such as \'\'[[Neochoerus]]\'\',<ref name="Vucetich 2005"/><ref name="Deschamp 2007"/> but more recently have adopted the classification of Hydrochoerinae within Caviidae.<ref name="Cerdeño 2019">{{cite journal|last1=Cerdeño |first1=E. |last2=Pérez |first2=M.E. |last3=Deschamps |first3=C.M. |last4=Contreras |',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '|last1=Cerdeño |first1=E. |last2=Pérez |first2=M.E. |last3=Deschamps |first3=C.M. |last4=Contreras |first4=V.H. |year=2019 |title=A new capybara from the late Miocene of San Juan Province, Argentina, and its phylogenetic implications |journal=Acta Palaeontologica Polonica |volume=64 |issue=1 |pages=199–212 |doi=10.4202/app.00544.2018|doi-access=free |hdl=11336/117299 |hdl-access=free }}</ref> The taxonomy of fossil hydrochoerines is also in a state of flux. In recent years, the diversity of foss',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'taxonomy of fossil hydrochoerines is also in a state of flux. In recent years, the diversity of fossil hydrochoerines has been substantially reduced.<ref name="Vucetich 2005"/><ref name="Deschamp 2007"/> This is largely due to the recognition that capybara molar teeth show strong variation in shape over the life of an individual. In one instance, material once referred to four genera and seven species on the basis of differences in molar shape is now thought to represent differently aged individ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'cies on the basis of differences in molar shape is now thought to represent differently aged individuals of a single species, \'\'Cardiatherium paranense\'\'.<ref name="Vucetich 2005"/>\nAmong fossil species, the name "capybara" can refer to the many species of Hydrochoerinae that are more closely related to the modern \'\'Hydrochoerus\'\' than to the "cardiomyine" rodents like \'\'Cardiomys\'\'. The fossil genera \'\'Cardiatherium\'\', \'\'Phugatherium\'\', \'\'Hydrochoeropsis\'\', and \'\'Neochoerus\'\' are all capybaras ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'nera \'\'Cardiatherium\'\', \'\'Phugatherium\'\', \'\'Hydrochoeropsis\'\', and \'\'Neochoerus\'\' are all capybaras under that concept.<ref name="Cerdeño 2019" />\n\n==Description==\n{{multiple image\n | image1 = Taxidermy specimen of Capybara (Hydrochoerus hydrochaeris).jpg\n | alt1 = Taxidermy specimen of a capybara\n | image2 = Capybara skeleton.jpg\n | alt2 = Skeleton of a capybara\n | footer = From left to right: Taxidermy specimen and skeleton of a capybara\n | align = left\n}}\nThe capybara has a heavy, barrel-shap',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'xidermy specimen and skeleton of a capybara\n | align = left\n}}\nThe capybara has a heavy, barrel-shaped body and short head, with reddish-brown fur on the upper part of its body that turns yellowish-brown underneath. Its sweat glands can be found in the surface of the hairy portions of its skin, an unusual trait among rodents.<ref name="r4" /> The animal lacks [[Fur#Down hair|down hair]], and its [[Fur#Guard hair|guard hair]] differs little from over hair.<ref>{{Cite web|url=https://www.worldatla',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "[Fur#Guard hair|guard hair]] differs little from over hair.<ref>{{Cite web|url=https://www.worldatlas.com/articles/10-delightful-facts-about-capybaras.html|title=The Cabybara – 10 Facts About the World's Largest Rodent|website=WorldAtlas|date=26 July 2019|language=en|access-date=2020-03-18}}</ref>\n\nAdult capybaras grow to {{convert|106|to|134|cm|ft|abbr=on}} in length, stand {{convert|50|to|62|cm|in|abbr=on}} tall at the [[withers]], and typically weigh {{convert|35|to|66|kg|lb|abbr=on}}, with a",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'in|abbr=on}} tall at the [[withers]], and typically weigh {{convert|35|to|66|kg|lb|abbr=on}}, with an average in the Venezuelan [[llanos]] of {{convert|48.9|kg|lb|abbr=on}}.<ref name=Arkive>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/#text=Facts Capybara] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/#text=Facts#text=Facts |date=2012-01-03 }}, Arkive</ref><ref name="Smithsonian"/><ref name="Palm Beach Zoo"/> Fem',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ext=Facts |date=2012-01-03 }}, Arkive</ref><ref name="Smithsonian"/><ref name="Palm Beach Zoo"/> Females are slightly heavier than males. The top recorded weights are {{convert|91|kg|lb|abbr=on}} for a wild female from Brazil and {{convert|73.5|kg|lb|abbr=on}} for a wild male from Uruguay.<ref name=r4/><ref name=r3/> Also, an 81&nbsp;kg individual was reported in São Paulo in 2001 or 2002.<ref>{{cite journal |last1=Ferraz |first1=Katia Maria Paschoaletto Micchi de Barros |last2=Bonach |first2=Ke',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "ite journal |last1=Ferraz |first1=Katia Maria Paschoaletto Micchi de Barros |last2=Bonach |first2=Kelly |last3=Verdade |first3=Luciano Martins |title=Relationship between body mass and body length in capybaras (''Hydrochoerus hydrochaeris'') |journal=Biota Neotropica |date=2005 |volume=5 |issue=1 |pages=197–200 |doi=10.1590/S1676-06032005000100020 |doi-access=free }}</ref> The [[dental formula]] is {{DentalFormula|upper=1.0.1.3|lower=1.0.1.3}}. Capybaras have slightly [[Interdigital webbing|webb",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 's {{DentalFormula|upper=1.0.1.3|lower=1.0.1.3}}. Capybaras have slightly [[Interdigital webbing|webbed]] feet and [[Vestigiality|vestigial]] tails.<ref name=r4/> Their hind legs are slightly longer than their forelegs; they have three toes on their rear feet and four toes on their front feet.<ref name="enchantedlearning.com">{{cite web|url=http://www.enchantedlearning.com/subjects/mammals/rodent/Capybaraprintout.shtml |title=Capybara Printout |publisher=Enchantedlearning.com |access-date=2013-05',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'apybaraprintout.shtml |title=Capybara Printout |publisher=Enchantedlearning.com |access-date=2013-05-27}}</ref> Their muzzles are blunt, with nostrils, and the eyes and ears are near the top of their heads.\n\nIts [[karyotype]] has [[Diploid|2n]] = 66 and [[Fundamental number|FN]] = 102, meaning it has 66 chromosomes with a total of 102 arms.<ref name=msw3/><ref name=r4/>\n\n==Ecology==\n[[File:Cattle tyrant (Machetornis rixosa) on Capybara.jpg|thumb|left|[[Cattle tyrant]] on a capybara]]\n\nCapybaras ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'tyrant (Machetornis rixosa) on Capybara.jpg|thumb|left|[[Cattle tyrant]] on a capybara]]\n\nCapybaras are [[semiaquatic]] mammals<ref name="Palm Beach Zoo"/> found throughout all countries of South America except [[Chile]].<ref name="Bristol"/> They live in densely forested areas near bodies of water, such as lakes, rivers, swamps, ponds, and marshes,<ref name="Smithsonian"/> as well as flooded savannah and along rivers in the tropical rainforest. They are superb swimmers and can hold their breath',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'nnah and along rivers in the tropical rainforest. They are superb swimmers and can hold their breath underwater for up to five minutes at a time. Capybara have flourished in cattle ranches. They roam in home ranges averaging {{convert|10|ha|acre|abbr=off}} in high-density populations.<ref name=r4/>\n\nMany escapees from captivity can also be found in similar watery habitats around the world. Sightings are fairly common in [[Florida]], although a breeding population has not yet been confirmed.<ref>',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'gs are fairly common in [[Florida]], although a breeding population has not yet been confirmed.<ref>{{cite web|url=http://myfwc.com/wildlifehabitats/nonnatives/mammals/capybara/|title=Nonnatives – Capybara|website=myfwc.com|access-date=2013-08-30|archive-date=2014-04-06|archive-url=https://web.archive.org/web/20140406221051/http://myfwc.com/wildlifehabitats/nonnatives/mammals/capybara/}}</ref> In 2011, one specimen was spotted on the [[Central Coast (California)|Central Coast of California]].<re',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "2011, one specimen was spotted on the [[Central Coast (California)|Central Coast of California]].<ref>{{cite news|url=http://www.latimes.com/news/local/la-me-0818-capybara-20110818,0,104462.story|title=A gnawing question answered: It's a capybara roaming Paso Robles|last=Mather|first=Kate|date=18 August 2011|work=[[Los Angeles Times]]|access-date=10 January 2012}}</ref> These escaped populations occur in areas where prehistoric capybaras inhabited; [[late Pleistocene]] capybaras inhabited Florid",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ccur in areas where prehistoric capybaras inhabited; [[late Pleistocene]] capybaras inhabited Florida<ref>{{Cite journal|url=https://bioone.org/journals/proceedings-of-the-academy-of-natural-sciences-of-philadelphia/volume-167/issue-1/053.167.0105/A-Late-Pleistocene-capybara-Rodentia-Caviidae-Hydrochoerinae-from-near-Houston/10.1635/053.167.0105.short|doi=10.1635/053.167.0105|title=A Late Pleistocene capybara (Rodentia, Caviidae, Hydrochoerinae) from near Houston, Texas, USA, with a brief review',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "ene capybara (Rodentia, Caviidae, Hydrochoerinae) from near Houston, Texas, USA, with a brief review of North American fossil capybaras|year=2020|last1=Baskin|first1=Jon|last2=Gervais|first2=P. Darrow|last3=Gervais|first3=Camille J.|journal=Proceedings of the Academy of Natural Sciences of Philadelphia|volume=167|issue=1 |page=57|bibcode=2020PANSP.167...57B |s2cid=216241471|url-access=subscription}}</ref> and ''[[Hydrochoerus hesperotiganites]]'' in [[California]] and ''[[Hydrochoerus gaylordi]]",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "}}</ref> and ''[[Hydrochoerus hesperotiganites]]'' in [[California]] and ''[[Hydrochoerus gaylordi]]'' in [[Grenada]], and feral capybaras in North America may actually fill the ecological niche of the Pleistocene species.<ref>Erick J. Lundgren, Daniel Ramp, John Rowan, Owen Middleton, Simon D. Schowanek, Oscar Sanisidro, Scott P. Carroll, Matt Davis, Christopher J. Sandom, Jens-Christian Svenning, Arian D. Wallach, James A. Estes, 2020, ''[https://www.pnas.org/content/117/14/7871 Introduced her",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ", Arian D. Wallach, James A. Estes, 2020, ''[https://www.pnas.org/content/117/14/7871 Introduced herbivores restore Late Pleistocene ecological functions]'', PNAS, 117 (14), pp.7871-7878, [[Proceedings of the National Academy of Sciences of the United States of America]]</ref>\n\n===Diet and predation===\n[[File:Capybara Eating Hay 11 11 2018.jpg|thumb|A capybara eating hay at [[Franklin Park Zoo]], Boston, Massachusetts]]\n\nCapybaras are [[herbivore]]s, grazing mainly on grasses and [[aquatic plant",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'Boston, Massachusetts]]\n\nCapybaras are [[herbivore]]s, grazing mainly on grasses and [[aquatic plants]],<ref name="Smithsonian"/><ref name="RevBiolTrop"/> as well as fruit and tree bark.<ref name="Palm Beach Zoo"/> They are very selective feeders<ref name="Quintana 1998"/> and feed on the leaves of one species and disregard other species surrounding it. They eat a greater variety of plants during the dry season, as fewer plants are available. While they eat grass during the wet season, they have',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'the dry season, as fewer plants are available. While they eat grass during the wet season, they have to switch to more abundant reeds during the dry season.<ref name="Barreto 1998"/> Plants that capybaras eat during the summer lose their nutritional value in the winter, so they are not consumed at that time.<ref name="Quintana 1998"/> The capybara\'s jaw hinge is not perpendicular, so they chew food by grinding back-and-forth rather than side-to-side.<ref name="SFZoo"/> Capybaras are [[coprophago',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'd by grinding back-and-forth rather than side-to-side.<ref name="SFZoo"/> Capybaras are [[coprophagous|autocoprophagous]],<ref name="taronga-zoo"/> meaning they eat their own feces as a source of bacterial [[gut flora]], to help digest the [[cellulose]] in the grass that forms their normal diet, and to extract the maximum protein and vitamins from their food. They also regurgitate food to masticate again, similar to cud-chewing by cattle.<ref name="taronga-zoo">{{cite web |title=Meet Taronga\'s C',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'e again, similar to cud-chewing by cattle.<ref name="taronga-zoo">{{cite web |title=Meet Taronga\'s Capybaras |url=https://taronga.org.au/sydney-zoo/must-see/capybaras |website=Taronga Zoo |access-date=29 December 2021 |ref=taronga-zoo}}</ref><ref name="Lord-Rexford 1994"/> Like other rodents, a capybara\'s front teeth grow continually to compensate for the constant wear from eating grasses;<ref name="Bristol"/> their cheek teeth also grow continuously.<ref name="SFZoo"/> \n\nLike its relative the g',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'e="Bristol"/> their cheek teeth also grow continuously.<ref name="SFZoo"/> \n\nLike its relative the guinea pig, the capybara does not have the capacity to synthesize [[vitamin C]], and capybaras not supplemented with vitamin C in captivity have been reported to develop [[Periodontal disease|gum disease]] as a sign of [[scurvy]].<ref name=r2/>\n\nThe maximum lifespan of the capybara is 8 to 10 years,<ref name=r6/> but in the wild capybaras usually do not live longer than four years because of predat',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ref name=r6/> but in the wild capybaras usually do not live longer than four years because of predation from South American [[big cats]] such as [[jaguar]]s and [[cougar]]s and from non-mammalian predators such as [[caiman]]s, [[Eunectes murinus|green anaconda]]s and [[piranha]]s.<ref name="Bristol"/><ref name="SoundsandColours"/>\n\n==Social organization==\n[[File:Capybara (Hydrochoerus hydrochaeris) alpha male.JPG|thumb|right|Capybaras have a scent gland on their noses.]]\n\nCapybaras are known to ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ') alpha male.JPG|thumb|right|Capybaras have a scent gland on their noses.]]\n\nCapybaras are known to be [[gregarious]]. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles.<ref name="Alho 1987"/> Capybara groups can consist of as many as 50 or 100 individuals during the dry season<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> when the animals ga',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'during the dry season<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.<ref name="Macdonald 1981"/> They can make dog-like barks<ref name="Lord-Rexford 1994"/> when threatened or when females are herding young.<ref name="Murphey 1985"/>\n\nCapybaras have two types of [[scent gland]]s: a morrillo, located on the snout, and [[anal gland]]s. Both sexes have these gland',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '[[scent gland]]s: a morrillo, located on the snout, and [[anal gland]]s. Both sexes have these glands, but males have much larger morrillos and use their anal glands more frequently. The anal glands of males are also lined with detachable hairs. A crystalline form of scent secretion is coated on these hairs and is released when in contact with objects such as plants. These hairs have a longer-lasting scent mark and are tasted by other capybaras. Capybaras scent-mark by rubbing their morrillos on',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ing scent mark and are tasted by other capybaras. Capybaras scent-mark by rubbing their morrillos on objects, or by walking over scrub and marking it with their anal glands. Capybaras can spread their scent farther by urinating; however, females usually mark without urinating and scent-mark less frequently than males overall. Females mark more often during the wet season when they are in [[estrus]]. In addition to objects, males also scent-mark females.<ref name="Macdonald 1984"/>\n\n===Reproducti',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ']. In addition to objects, males also scent-mark females.<ref name="Macdonald 1984"/>\n\n===Reproduction===\n[[File:Young capybaras.jpg|thumb|left|Mother with typical litter of about four pups]]\nWhen in [[estrus]], the female\'s scent changes subtly and nearby males begin pursuit.<ref name="Herrera 1993">{{cite journal|doi=10.1093/beheco/4.2.114|title= Aggression, dominance, and mating success among capybara males (\'\'Hydrochaeris hypdrochaeris\'\')|year=1993|last1=Herrera|first1=Emilio A.|last2=MacDon',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'apybara males (\'\'Hydrochaeris hypdrochaeris\'\')|year=1993|last1=Herrera|first1=Emilio A.|last2=MacDonald|first2=David W.|journal=[[Behavioral Ecology (journal)|Behavioral Ecology]]|volume=4|issue=2|page=114}}</ref> In addition, a female alerts males she is in estrus by whistling through her nose.<ref name="Lord-Rexford 1994"/> During mating, the female has the advantage and mating choice. Capybaras mate only in water, and if a female does not want to mate with a certain male, she either submerges',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ' mate only in water, and if a female does not want to mate with a certain male, she either submerges or leaves the water.<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> Dominant males are highly protective of the females, but they usually cannot prevent some of the subordinates from copulating. The larger the group, the harder it is for the male to watch all the females. Dominant males secure significantly more matings than each subordinate, but subordinate males, as a class, are res',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ' secure significantly more matings than each subordinate, but subordinate males, as a class, are responsible for more matings than each dominant male.<ref name="Herrera 1993"/> The lifespan of the capybara\'s sperm is longer than that of other rodents.<ref name=r1/> Capybara [[gestation]] is 130–150 days, and produces a litter of four young on average, but may produce between one and eight in a single litter.<ref name=r4/> Birth is on land and the female rejoins the group within a few hours of de',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'gle litter.<ref name=r4/> Birth is on land and the female rejoins the group within a few hours of delivering the newborn capybaras, which join the group as soon as they are mobile. Within a week, the young can eat grass, but continue to suckle—from any female in the group—until weaned around 16 weeks. The young form a group within the main group.<ref name="Bristol"/> [[Alloparenting]] has been observed in this species.<ref name="Macdonald 1981"/> Breeding peaks between April and May in Venezuela',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'erved in this species.<ref name="Macdonald 1981"/> Breeding peaks between April and May in Venezuela and between October and November in [[Mato Grosso]], Brazil.<ref name=r4/>\n\n===Activities===\nThough quite agile on land, capybaras are equally at home in the water. They are excellent swimmers, and can remain completely submerged for up to five minutes,<ref name="Smithsonian"/> an ability they use to evade predators. Capybaras can sleep in water, keeping only their noses out. As temperatures incr',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'to evade predators. Capybaras can sleep in water, keeping only their noses out. As temperatures increase during the day, they wallow in water and then graze during the late afternoon and early evening.<ref name=r4/> They also spend time wallowing in mud.<ref name="enchantedlearning.com"/> They rest around midnight and then continue to graze before dawn.<ref name="r4" />\n\n===Communication===\nCapybaras communicate using barks, chirps, whistles, huffs, and purrs.<ref>{{cite web | url=https://zoo.sa',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ras communicate using barks, chirps, whistles, huffs, and purrs.<ref>{{cite web | url=https://zoo.sandiegozoo.org/animals/capybara | title=Capybara }}</ref>\n\n[[File:Capybara Ueno Zoo 2009.ogv|thumb|A capybara in captivity, 2009]]\n\n==Conservation and human interaction==\nCapybaras are not considered a threatened species;<ref name="iucn status 19 November 2021" /> their population is stable throughout most of their South American range, though in some areas hunting has reduced their numbers.<ref na',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 't most of their South American range, though in some areas hunting has reduced their numbers.<ref name="Smithsonian"/><ref name="Bristol"/> Capybaras are hunted for their meat and pelts in some areas,<ref name="inRich" /> and otherwise killed by humans who see their grazing as competition for livestock. In some areas, they are farmed, which has the effect of ensuring the wetland habitats are protected. Their survival is aided by their ability to breed rapidly.<ref name="Bristol" />\n\nCapybaras ha',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'cted. Their survival is aided by their ability to breed rapidly.<ref name="Bristol" />\n\nCapybaras have adapted well to urbanization in South America. They can be found in many areas in zoos and parks,<ref name="SFZoo" /> and may live for 12 years in captivity, more than double their wild lifespan.<ref name="Bristol" /> Capybaras are docile and usually allow humans to pet and hand-feed them, but physical contact is normally discouraged, as their [[tick]]s can be [[vector (epidemiology)|vectors]] ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ysical contact is normally discouraged, as their [[tick]]s can be [[vector (epidemiology)|vectors]] to [[Rocky Mountain spotted fever]].<ref>{{cite web|url=http://drauziovarella.com.br/audios-videos/estacao-medicina/febre-maculosa/ |title=Febre maculosa: "Os médicos no Brasil não conhecem a doença|date=12 April 2011|trans-title= Rocky Mountain spotted fever: Brazilian doctors unaware of the disease |language=pt |publisher=drauziovarella.com.br |access-date=2015-08-13}}</ref> The [[European Assoc',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'e |language=pt |publisher=drauziovarella.com.br |access-date=2015-08-13}}</ref> The [[European Association of Zoos and Aquaria]] asked [[Drusillas Park]] in [[Alfriston]], [[Sussex]], England, to keep the [[studbook]] for capybaras, to monitor captive populations in Europe. The studbook includes information about all births, deaths and movements of capybaras, as well as how they are related.<ref>{{cite web|url=http://www.drusillas.co.uk/conservation-1 |title=Conservation at Drusillas Park |publi',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '{cite web|url=http://www.drusillas.co.uk/conservation-1 |title=Conservation at Drusillas Park |publisher=Drusillas.co.uk |access-date=2013-05-27}}</ref>\n\nCapybaras are farmed for meat and skins in South America.<ref name="SDzoo"/> The meat is considered unsuitable to eat in some areas, while in other areas it is considered an important source of protein.<ref name=r4/> In parts of South America, especially in Venezuela, capybara meat is popular during [[Lent]] and [[Holy Week]] as the Catholic Ch',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'pecially in Venezuela, capybara meat is popular during [[Lent]] and [[Holy Week]] as the Catholic Church (according to a legend) previously issued special dispensation to allow it to be eaten while other meats are [[Fasting and abstinence in the Catholic Church|generally forbidden]].<ref name="NYSun"/><ref name="NYTimes2007">{{Cite news |last=Romero |first=Simon |date=2007-03-21 |title=In Venezuela, Rodents Can Be a Delicacy |url=https://www.nytimes.com/2007/03/21/world/americas/21rodent.html |a',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'a, Rodents Can Be a Delicacy |url=https://www.nytimes.com/2007/03/21/world/americas/21rodent.html |archive-url=https://archive.today/20131014211839/http://www.nytimes.com/2007/03/21/world/americas/21rodent.html?_r=0 |archive-date=14 Oct 2013 |access-date=2021-04-27 |work=The New York Times |language=en-US |issn=0362-4331 |quote=Legend has it that eating capybara, known here as chigüire (pronounced chee-GWEE-reh), got a boost in the 18th century when the local clergy asked the Vatican to give cap',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ' chee-GWEE-reh), got a boost in the 18th century when the local clergy asked the Vatican to give capybara the status of fish. (...) It remains more popular in Venezuela\'s rural interior than in the capital.}}</ref> There is widespread perception in Venezuela that consumption of capybaras is exclusive to rural people.<ref name="NYTimes2007"/>\n\nIn August 2021, Argentine and international media reported that capybaras had been disturbing residents of [[Nordelta]], an affluent gated community north ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ted that capybaras had been disturbing residents of [[Nordelta]], an affluent gated community north of [[Buenos Aires]] built atop the local capybara\'s preexisting wetland habitat. This inspired social media users to jokingly adopt the capybara as a symbol of [[class struggle]] and [[communism]].<ref name="TheGuardian_20210822">{{cite web|title=Attack of the giant rodents or class war? Argentina\'s rich riled by new neighbors|newspaper=[[The Guardian]] |date=22 August 2021 |url=https://www.thegua',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': " rich riled by new neighbors|newspaper=[[The Guardian]] |date=22 August 2021 |url=https://www.theguardian.com/world/2021/aug/22/argentina-capybaras-giant-rodents-gated-community |last=Goñi |first=Uki}}</ref> Brazilian Lyme-like [[borreliosis]] likely involves capybaras as reservoirs and ''[[Amblyomma]]'' and ''[[Rhipicephalus]]'' ticks as vectors.<ref>{{cite journal |last1=Basile |first1=Roberta Carvalho |last2=Yoshinari |first2=Natalino Hajime |last3=Mantovani |first3=Elenice |last4=Bonoldi |fi",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'arvalho |last2=Yoshinari |first2=Natalino Hajime |last3=Mantovani |first3=Elenice |last4=Bonoldi |first4=Virgínia Nazário |last5=Macoris |first5=Delphim da Graça |last6=Queiroz-Neto |first6=Antonio de |title=Brazilian borreliosis with special emphasis on humans and horses |journal=Brazilian Journal of Microbiology |date=4 October 2016 |volume=48 |issue=1 |pages=167–172 |doi=10.1016/j.bjm.2016.09.005 |pmid=27769883 |pmc=5220628 }}</ref>\n\nA [[Animal cafe#Capybara café|Capybara café]] in [[St. Augu',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '05 |pmid=27769883 |pmc=5220628 }}</ref>\n\nA [[Animal cafe#Capybara café|Capybara café]] in [[St. Augustine, Florida|St. Augustine]], [[Florida]]  allows visitors to interact with and give head scratches to the rodents.<ref>{{cite news|title=Giant rodents cuddle with visitors at the Capybara Cafe in Florida|url=https://apnews.com/article/florida-capybara-cafe-st-augustine-54ce3807f084e9de61f72a79c6633e10|newspaper=Associated Press News|date=April 12, 2025}}</ref>\n\n== In popular culture ==\n[[Izu Sh',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '33e10|newspaper=Associated Press News|date=April 12, 2025}}</ref>\n\n== In popular culture ==\n[[Izu Shaboten Zoo]] and other zoos in Japan have created [[onsen|hot spring baths]] for capybaras.<ref name="reuters">{{cite web|url=https://www.reuters.com/article/us-olympics-2020-capybara-idCAKBN1ZY0FY|title=Olympics and Year of the Rat give starring role to Japan\'s capybaras|website=[[Reuters]]|first=Sakura|last=Murakami|date=4 February 2020|access-date=23 October 2021}}</ref> Video clips of the bath',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'akura|last=Murakami|date=4 February 2020|access-date=23 October 2021}}</ref> Video clips of the bathing capybaras have gained millions of views.<ref name="reuters"/> The capybaras have influenced an [[anime]] character named \'\'Kapibara-san\'\', and a series of merchandise such as [[plush toy]]s.<ref>{{cite web|url=https://qz.com/986398/how-the-capybara-the-worlds-largest-rodent-became-a-superstar-in-japan/|title=How the world\'s largest rodent became a superstar in Japan|website=[[Quartz (publicati',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "-japan/|title=How the world's largest rodent became a superstar in Japan|website=[[Quartz (publication)|Quartz]]|first=Isabella|last=Steger|date=19 May 2017|access-date=23 October 2021}}</ref> \n\nCapybaras have long been a figure in [[Internet meme|meme culture]],<ref>{{cite news |last1=Diaz |first1=Ana |title=Capybaras are taking over TikTok and we're better for it |url=https://www.polygon.com/23620358/capybara-tiktok-meme-audio-trend |access-date=28 February 2025 |work=Polygon |date=March 2, 20",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '20358/capybara-tiktok-meme-audio-trend |access-date=28 February 2025 |work=Polygon |date=March 2, 2023}}</ref> particularly in the 2020s.<ref name="euronewsmeme">{{cite news |last1=Mouriquand |first1=David |title=Why are capybaras systematically taking over social media? |url=https://www.euronews.com/culture/2023/04/12/why-are-capybaras-systematically-taking-over-social-media |access-date=24 February 2025 |work=Euro News |date=December 4, 2023}}</ref> In 2022, [[Peronists]] in Argentina presente',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ary 2025 |work=Euro News |date=December 4, 2023}}</ref> In 2022, [[Peronists]] in Argentina presented them as figures of class struggle after the disturbances in Nordelta.<ref name=TheGuardian_20210822 /> Common meme formats pair capybaras with the song "[[After Party (song)|After Party]]" by [[Don Toliver]].<ref name="euronewsmeme"/><ref>{{Cite web |last=Lopez |first=Sophia |date=2022-08-01 |title=Capybaras are taking over the internet |url=https://thegauntlet.ca/2022/08/01/capybaras-are-taking',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "e=Capybaras are taking over the internet |url=https://thegauntlet.ca/2022/08/01/capybaras-are-taking-over-the-internet/ |access-date=2022-09-02 |website=The Gauntlet |language=en-US}}</ref>\n\n==See also==\n{{Portal|Mammals|South America}}\n* ''[[Josephoartigasia monesi]]'', an extinct species identified as the largest known rodent ever\n* [[Kurloff cell]], a type of cell found in capybaras and guinea pigs\n* ''[[Capybara Walking]]'', a historical animal locomotion film by [[Eadweard Muybridge]]\n\n==No",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'pigs\n* \'\'[[Capybara Walking]]\'\', a historical animal locomotion film by [[Eadweard Muybridge]]\n\n==Notes==\n<references group="note" />\n{{notelist}}\n\n==References==\n{{Reflist|30em|refs=\n<ref name="Bristol">[http://www.bristolzoo.org.uk/learning/animals/mammals/capybara Bristol Zoo Gardens (UK) \'\'Capybara\'\'] {{webarchive|url=https://web.archive.org/web/20070918183854/http://www.bristolzoo.org.uk/learning/animals/mammals/capybara |date=2007-09-18 }}. Bristolzoo.org.uk. Retrieved on 2011-12-07.</ref>',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ning/animals/mammals/capybara |date=2007-09-18 }}. Bristolzoo.org.uk. Retrieved on 2011-12-07.</ref>\n<ref name="Barreto 1998">{{cite journal |title=Foraging patterns of capybaras in a seasonally flooded savanna of Venezuela| jstor=2559868|doi=10.1017/S0266467498000078 |year=1998 |last1=Barreto |first1=Guillermo R. |last2=Herrera |first2=Emilio A. |journal=Journal of Tropical Ecology |volume=14 | issue=1| pages=87–98| s2cid=84982123}}</ref>\n<ref name="Quintana 1998">{{cite journal |last1=Quintana',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ssue=1| pages=87–98| s2cid=84982123}}</ref>\n<ref name="Quintana 1998">{{cite journal |last1=Quintana |first1=R.D. |last2=Monge |first2=S. |last3=Malvárez |first3=A.I. |title=Feeding patterns of capybara \'\'Hydrochaeris hydrochaeris\'\' (Rodentia, Hydrochaeridae) and cattle in the non-insular area of the Lower Delta of the Paraná River, Argentina |journal=Mammalia |date=1998 |volume=62 |issue=1 |pages=37–52 |doi=10.1515/mamm.1998.62.1.37 |s2cid=83976640 }}</ref>\n<ref name=r6>Burton M and Burton R. (',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '=37–52 |doi=10.1515/mamm.1998.62.1.37 |s2cid=83976640 }}</ref>\n<ref name=r6>Burton M and Burton R. (2002) \'\'The International Wildlife Encyclopedia\'\'. Marshall Cavendish, {{ISBN|0-7614-7269-X}}, p. 384</ref>\n<ref name="SoundsandColours">[http://soundsandcolours.com/subjects/south-american-nature/capybara-the-master-of-the-grasses-pest-or-prey-3937/ Capybara, the master of the grasses: pest or prey]  Sounds and Colours. Retrieved on 23 January 2011.</ref>\n<ref name="SFZoo">[https://web.archive.or',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ']  Sounds and Colours. Retrieved on 23 January 2011.</ref>\n<ref name="SFZoo">[https://web.archive.org/web/20070614005832/http://www.sfzoo.org/cgi-bin/animals.py?ID=90 Capybara. \'\'Hydrochaeris hydrochaeris\'\']. San Francisco Zoo</ref>\n<ref name="SDzoo">{{cite web  | date = October 2008  | publisher = San Diego Zoo  | title = Capybara, \'\'Hydrochoerus hydrochaeris\'\'  | url = http://library.sandiegozoo.org/factsheets/capybara/capybara.htm  | access-date = 22 June 2011  | archive-url = https://web.arc',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '.org/factsheets/capybara/capybara.htm  | access-date = 22 June 2011  | archive-url = https://web.archive.org/web/20110930051431/http://library.sandiegozoo.org/factsheets/capybara/capybara.htm  | archive-date = 30 September 2011  }}</ref>\n<ref name="Alho 1987">{{cite journal |last1=Alho |first1=Cleber J.R. |last2=Rondon |first2=Nelson L. |title=Habitats, population densities, and social structure of capybaras (\'\'Hydrochaeris Hydrochaeris\'\', Rodentia) in the Pantanal, Brazil |journal=[[Revista Bra',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'f capybaras (\'\'Hydrochaeris Hydrochaeris\'\', Rodentia) in the Pantanal, Brazil |journal=[[Revista Brasileira de Zoologia]] |date=1987 |volume=4 |issue=2 |pages=139–149 |doi=10.1590/s0101-81751987000200006 |doi-access=free }}</ref>\n<ref name="Lord-Rexford 1994">{{cite journal |last1=Lord |first1=Rexford D. |title=A descriptive account of capybara behaviour |journal=Studies on Neotropical Fauna and Environment |date=March 1994 |volume=29 |issue=1 |pages=11–22 |doi=10.1080/01650529409360912 |bibcode',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'nvironment |date=March 1994 |volume=29 |issue=1 |pages=11–22 |doi=10.1080/01650529409360912 |bibcode=1994SNFE...29...11L }}</ref>\n<ref name="Macdonald 1981">{{cite journal |last1=Macdonald |first1=D. W. |title=Dwindling resources and the social behaviour of Capybaras, (\'\'Hydrochoerus hydrochaeris\'\') (Mammalia) |journal=Journal of Zoology |date=July 1981 |volume=194 |issue=3 |pages=371–391 |doi=10.1111/j.1469-7998.1981.tb04588.x }}</ref>\n<ref name="Murphey 1985">{{cite journal |last1=Murphey |fir',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '1111/j.1469-7998.1981.tb04588.x }}</ref>\n<ref name="Murphey 1985">{{cite journal |last1=Murphey |first1=Robert M. |last2=Mariano |first2=Jorge S. |last3=Moura Duarte |first3=Francisco A. |title=Behavioral observations in a capybara colony (\'\'Hydrochoerus hydrochaeris\'\') |journal=Applied Animal Behaviour Science |date=May 1985 |volume=14 |issue=1 |pages=89–98 |doi=10.1016/0168-1591(85)90040-1 }}</ref>\n<ref name=r1>{{cite journal |last1=Paula |first1=T.A.R. |last2=Chiarini-Garcia |first2=H. |last3',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ef>\n<ref name=r1>{{cite journal |last1=Paula |first1=T.A.R. |last2=Chiarini-Garcia |first2=H. |last3=França |first3=L.R. |title=Seminiferous epithelium cycle and its duration in capybaras (Hydrochoerus hydrochaeris) |journal=Tissue and Cell |date=June 1999 |volume=31 |issue=3 |pages=327–334 |doi=10.1054/tice.1999.0039 |pmid=10481304 }}</ref>\n<ref name=r2>{{cite journal |last1=Cueto |first1=Gerardo Ruben |last2=Allekotte |first2=Roman |last3=Kravetz |first3=Fernando Osvaldo |title=Scurvy in capyb',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ' Ruben |last2=Allekotte |first2=Roman |last3=Kravetz |first3=Fernando Osvaldo |title=Scurvy in capybaras bred in captivity in Argentine |journal=Journal of Wildlife Diseases |date=January 2000 |volume=36 |issue=1 |pages=97–101 |doi=10.7589/0090-3558-36.1.97 |pmid=10682750 |s2cid=6491859 |doi-access=free }}</ref>\n<ref name=r3>[http://www.waza.org/virtualzoo/factsheet.php?id=110-020-001-001&view=Rodents%20and%20Hares&main=virtualzoo World Association of Zoos and Aquariums]. [[World Association of ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ents%20and%20Hares&main=virtualzoo World Association of Zoos and Aquariums]. [[World Association of Zoos and Aquariums|WAZA]]. Retrieved on 2011-12-07.</ref>\n<ref name=r4>{{cite journal |last1=Mones |first1=Alvaro |last2=Ojasti |first2=Juhani |title=Hydrochoerus hydrochaeris |journal=Mammalian Species |date=16 June 1986 |issue=264 |pages=1–7 |doi=10.2307/3503784 |jstor=3503784 |s2cid=250991487 |doi-access=free }}</ref>\n<ref name="Smithsonian">[https://web.archive.org/web/20050930231549/http://na',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'i-access=free }}</ref>\n<ref name="Smithsonian">[https://web.archive.org/web/20050930231549/http://nationalzoo.si.edu/Animals/Amazonia/Facts/capybarafacts.cfm Capybara Facts.] [[Smithsonian National Zoological Park]]. Retrieved on 16 December 2007.</ref>\n<ref name="Palm Beach Zoo">[https://web.archive.org/web/20100620162726/http://palmbeachzoo.org/animals/capybara.html Capybara.] Palm Beach Zoo. Retrieved on 17 December 2007.</ref>\n<ref name="Macdonald 1984">{{cite journal |last1=Macdonald |first',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'trieved on 17 December 2007.</ref>\n<ref name="Macdonald 1984">{{cite journal |last1=Macdonald |first1=D. W. |last2=Krantz |first2=K. |last3=Aplin |first3=R. T. |title=Behavioral anatomical and chemical aspects of scent marking among Capybaras (\'\'Hydrochaeris hypdrochaeris\'\') (Rodentia: Caviomorpha) |journal=Journal of Zoology |date=March 1984 |volume=202 |issue=3 |pages=341–360 |doi=10.1111/j.1469-7998.1984.tb05087.x }}</ref>\n<ref name="RevBiolTrop">{{cite journal |last1=Forero-Montaña |first1=J',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '-7998.1984.tb05087.x }}</ref>\n<ref name="RevBiolTrop">{{cite journal |last1=Forero-Montaña |first1=Jimena |last2=Betancur |first2=Julio |last3=Cavelier |first3=Jaime |title=Dieta del capibara \'\'Hydrochaeris hydrochaeris\'\' (Rodentia: Hydrochaeridae) en Caño Limón, Arauca, Colombia |trans-title=Distribution and abundance of Caiman crocodilus in the Caño Negro National Wild Life Refuge, Costa Rica |language=es |journal=[[Revista de Biología Tropical]] |date=June 2003 |volume=51 |issue=2 |pages=571–',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'anguage=es |journal=[[Revista de Biología Tropical]] |date=June 2003 |volume=51 |issue=2 |pages=571–578 |url=https://www.scielo.sa.cr/scielo.php?script=sci_arttext&pid=S0034-77442003000200029 |pmid=15162749 }}</ref><ref name="NYSun">Ellsworth, Brian (24 March 2005). [http://www.nysun.com/article/11063 "In Days Before Easter, Venezuelans Tuck Into Rodent-Related Delicacy"] {{Webarchive|url=https://web.archive.org/web/20080705215536/http://www.nysun.com/article/11063 |date=5 July 2008 }}. \'\'[[New ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'web.archive.org/web/20080705215536/http://www.nysun.com/article/11063 |date=5 July 2008 }}. \'\'[[New York Sun]]\'\'.</ref>\n<ref name="inRich">Thompson, Andy (18 January 2008) [https://archive.today/20130204101346/http://www2.timesdispatch.com/lifestyles/2008/jan/18/-rtd_2008_01_18_0043-ar-147752/ Trip to South America gives new meaning to outdoors life]. Richmond Times.</ref>\n<ref name="Rowe 2002">{{cite journal |last1=Rowe |first1=Diane L. |last2=Honeycutt |first2=Rodney L. |title=Phylogenetic Rel',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'cite journal |last1=Rowe |first1=Diane L. |last2=Honeycutt |first2=Rodney L. |title=Phylogenetic Relationships, Ecological Correlates, and Molecular Evolution Within the Cavioidea (Mammalia, Rodentia) |journal=Molecular Biology and Evolution |date=March 2002 |volume=19 |issue=3 |pages=263–277 |doi=10.1093/oxfordjournals.molbev.a004080 |pmid=11861886 |doi-access=free }}</ref>\n<ref name="Vucetich 2005">{{cite journal |last1=Vucetich |first1=María G. |last2=Deschamps |first2=Cecilia M. |last3=Oliva',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': '05">{{cite journal |last1=Vucetich |first1=María G. |last2=Deschamps |first2=Cecilia M. |last3=Olivares |first3=Itatí |last4=Dozo |first4=María T. |title=Capybaras, size, shape, and time: A model kit |journal=Acta Palaeontologica Polonica |volume=50 |issue=2 |year=2005 |pages=259–272 |url=https://www.app.pan.pl/article/item/app50-259.html }}</ref>\n<ref name="Deschamp 2007">{{cite journal |last1=Deschamps |first1=Cecilia M. |last2=Olivares |first2=Itatí |last3=Vieytes |first3=Emma Carolina |last4',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'schamps |first1=Cecilia M. |last2=Olivares |first2=Itatí |last3=Vieytes |first3=Emma Carolina |last4=Vucetich |first4=María Guiomar |title=Ontogeny and diversity of the oldest capybaras (Rodentia: Hydrochoeridae; late Miocene of Argentina) |journal=Journal of Vertebrate Paleontology |date=12 September 2007 |volume=27 |issue=3 |pages=683–692 |doi=10.1671/0272-4634(2007)27[683:oadoto]2.0.co;2 |jstor=30126368 |s2cid=86217854 }}</ref>\n}}\n\n==External links==\n{{EB1911 poster|Capybara}}\n{{Wiktionary|ca',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': "=30126368 |s2cid=86217854 }}</ref>\n}}\n\n==External links==\n{{EB1911 poster|Capybara}}\n{{Wiktionary|capybara}}\n* {{cite web|title=Companionable Capybaras (18 Photos)|author=Alan Taylor|date=29 November 2018|website=The Atlantic|url=https://www.theatlantic.com/photo/2018/11/photos-companionable-capybaras/576991/}}\n* [https://animaldiversity.org/site/accounts/information/Hydrochoerus_hydrochaeris.html Animal Diversity Web ''Hydrochoerus hydrochaeris'']\n* [https://capybarafacts.com Capybara informati",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': " Animal Diversity Web ''Hydrochoerus hydrochaeris'']\n* [https://capybarafacts.com Capybara information]\n\n{{Caviidae nav}}\n{{Taxonbar|from=Q131538}}\n\n[[Category:Mammals described in 1766]]\n[[Category:Cavies]]\n[[Category:Herbivorous mammals]]\n[[Category:Mammals of Argentina]]\n[[Category:Mammals of Bolivia]]\n[[Category:Rodents of Brazil]]\n[[Category:Mammals of Colombia]]\n[[Category:Mammals of Ecuador]]\n[[Category:Mammals of French Guiana]]\n[[Category:Mammals of Guyana]]\n[[Category:Mammals of Paragu",
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ']]\n[[Category:Mammals of French Guiana]]\n[[Category:Mammals of Guyana]]\n[[Category:Mammals of Paraguay]]\n[[Category:Mammals of Peru]]\n[[Category:Mammals of Uruguay]]\n[[Category:Mammals of Venezuela]]\n[[Category:Articles containing video clips]]\n[[Category:Semiaquatic mammals]]\n[[Category:Animal taxa named by Carl Linnaeus]]\n[[Category:2020s in Internet culture]]\n[[Category:Internet memes introduced in the 2020s]]',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'd in the 2020s]]',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}]

# %%
search_tool.search('where do capybaras live?')
# Out:
# [{'title': 'Capybara',
#   'content': 'tyrant (Machetornis rixosa) on Capybara.jpg|thumb|left|[[Cattle tyrant]] on a capybara]]\n\nCapybaras are [[semiaquatic]] mammals<ref name="Palm Beach Zoo"/> found throughout all countries of South America except [[Chile]].<ref name="Bristol"/> They live in densely forested areas near bodies of water, such as lakes, rivers, swamps, ponds, and marshes,<ref name="Smithsonian"/> as well as flooded savannah and along rivers in the tropical rainforest. They are superb swimmers and can hold their breath',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'cted. Their survival is aided by their ability to breed rapidly.<ref name="Bristol" />\n\nCapybaras have adapted well to urbanization in South America. They can be found in many areas in zoos and parks,<ref name="SFZoo" /> and may live for 12 years in captivity, more than double their wild lifespan.<ref name="Bristol" /> Capybaras are docile and usually allow humans to pet and hand-feed them, but physical contact is normally discouraged, as their [[tick]]s can be [[vector (epidemiology)|vectors]] ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': ') alpha male.JPG|thumb|right|Capybaras have a scent gland on their noses.]]\n\nCapybaras are known to be [[gregarious]]. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles.<ref name="Alho 1987"/> Capybara groups can consist of as many as 50 or 100 individuals during the dry season<ref name="Lord-Rexford 1994"/><ref name="Macdonald 1981"/> when the animals ga',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'e="Bristol"/> their cheek teeth also grow continuously.<ref name="SFZoo"/> \n\nLike its relative the guinea pig, the capybara does not have the capacity to synthesize [[vitamin C]], and capybaras not supplemented with vitamin C in captivity have been reported to develop [[Periodontal disease|gum disease]] as a sign of [[scurvy]].<ref name=r2/>\n\nThe maximum lifespan of the capybara is 8 to 10 years,<ref name=r6/> but in the wild capybaras usually do not live longer than four years because of predat',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'},
#  {'title': 'Capybara',
#   'content': 'ref name=r6/> but in the wild capybaras usually do not live longer than four years because of predation from South American [[big cats]] such as [[jaguar]]s and [[cougar]]s and from non-mammalian predators such as [[caiman]]s, [[Eunectes murinus|green anaconda]]s and [[piranha]]s.<ref name="Bristol"/><ref name="SoundsandColours"/>\n\n==Social organization==\n[[File:Capybara (Hydrochoerus hydrochaeris) alpha male.JPG|thumb|right|Capybaras have a scent gland on their noses.]]\n\nCapybaras are known to ',
#   'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}]

# %%
index

# %%
# prep data
# saarch
# chunk 

# if new then store if not then add

# %%
# agent

# %%
# tool calling monitoring 

from pydantic_ai.messages import FunctionToolCallEvent

class NamedCallback:

    def __init__(self, agent):
        self.agent_name = agent.name

    async def print_function_calls(self, ctx, event):
        # Detect nested streams
        if hasattr(event, "__aiter__"):
            async for sub in event:
                await self.print_function_calls(ctx, sub)
            return

        if isinstance(event, FunctionToolCallEvent):
            tool_name = event.part.tool_name
            args = event.part.args
            print(f"TOOL CALL ({self.agent_name}): {tool_name}({args})")

    async def __call__(self, ctx, event):
        return await self.print_function_calls(ctx, event)

# %%
# wiki_instruction = """
# You are an intelligent assistant that gathers, indexes, and searches Wikipedia knowledge to answer user queries. Always follow this workflow step by step:

# 1. Parse the main keyword from the user’s query. Focus on the central topic of the question.
# 2. Use `wiki_search.get_keywords` to generate a list of related Wikipedia article titles for the main keyword.
# 3. Use `wiki_search.get_keyword_page` to fetch the raw wikitext content for each keyword.
# 4. Use `search_tool.add_entry` to chunk and index the fetched page content.
# 5. Use `search_tool.search` to search the indexed chunks for relevant information to answer the query.

# Rules to always follow:
# - Extract the main keyword accurately before performing any searches.
# - Ensure Wikipedia pages are successfully retrieved before indexing.
# - Never search raw Wikipedia content directly; always search indexed chunks.
# - Return a concise, clear, and factual answer to the user based on the retrieved content.

# Available tools:
# - `wiki_search.get_keywords`
# - `wiki_search.get_keyword_page`
# - `search_tool.add_entry`
# - `search_tool.search`
# """

# wiki_instruction = """
# You are a Wikipedia-based knowledge assistant that uses Wikipedia APIs and a local search index to answer user queries. Always follow this workflow step by step:

# 1. Extract the main keyword(s) from the user query.
#    - Focus on nouns, named entities, or central topics.
#    - Ignore stopwords and question words (e.g., "what", "how", "why", "the", "is").
#    - If multiple keywords exist, process all of them in parallel.

# 2. Use `wiki_search.get_keywords(keyword)` to generate related Wikipedia article titles for each main keyword.

# 3. Use `wiki_search.get_keyword_page(keyword_list)` to fetch the raw wikitext content for all retrieved article titles.

# 4. Use `search_tool.add_entry(data)` to chunk and index the fetched content.

# 5. Use `search_tool.search(query)` to search the indexed chunks for relevant information to answer the user query.

# Rules to always follow:
# - Never answer from your own memory — rely only on indexed Wikipedia content.
# - Ensure pages are successfully retrieved and indexed before searching.
# - If no relevant page is found, clearly state: “No related Wikipedia page was found for your query.”
# - Include which keyword(s) were used in the search when relevant.

# Available tools:
# - `wiki_search.get_keywords(keyword)`
# - `wiki_search.get_keyword_page(keyword_list)`
# - `search_tool.add_entry(data)`
# - `search_tool.search(query)`

# Output behavior:
# - Provide concise, clear, and factual answers synthesized from the indexed Wikipedia content.
# - Cite the keyword(s) used when applicable.
# """

# wiki_instruction = """
# You are an intelligent assistant that answers user queries using Wikipedia as a source.


# ### Follow this workflow strictly:
# 1. Parse the main keyword from the user query.
# 2. Call `wiki_search.get_keywords` to get **all related keywords**.
# 3. For each keyword in the returned list:
#    a. Call `wiki_search.get_keyword_page` to fetch the page for that keyword.
#    b. Call `search_tool.add_entry` to chunk and index the page content.
# 4. After all keyword pages have been successfully fetched and indexed:  
#    → Use the **original user query** (not just the keywords) as the input to `search_tool.search(query)` to find the most relevant chunks from the index.
# 5. Generate the final answer **based only on the retrieved indexed content**.  
#    Do not use prior knowledge or external data beyond the indexed Wikipedia content.

# ### Notes:
# - `get_keyword_page` is called **one keyword at a time**.
# - The agent must ensure **all keywords** from `get_keywords` are fetched and indexed before performing the final search.
# - The search query in step 4 must be the **user’s original query** to ensure relevance.
# """

wiki_instruction = """
You are an intelligent assistant that answers user queries using Wikipedia as the knowledge source.

### STRICT WORKFLOW (MUST FOLLOW EXACTLY):

1. **Parse the user query**:
   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.
   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".

2. Call `wiki_search.get_keywords(main_keyword)`  
   → This returns a **list of related keywords**.  
   Make sure to retrieve **all** related keywords, not just the first one.

3. For each keyword in the returned list:
   a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page content for that keyword.  
   b. Pass the retrieved data (title, content, and url) into `search_tool.add_entry` to chunk and index it.


4. After all keyword pages have been successfully fetched and indexed:  
   → Use the **original user query** (not just the keywords) as the input to `search_tool.search(query)` to find the most relevant chunks from the index.

5. Generate the final answer **based only on the retrieved indexed content**.  
   Do not use prior knowledge or external data beyond the indexed Wikipedia content.

### Important Notes:
- Always iterate through **all keywords** from `get_keywords` before performing the search.  
- Each `get_keyword_page` call must handle one keyword at a time.  
- Ensure `add_entry` is called after each keyword page retrieval.  
- The search query in step 4 must be the **user’s original query** to ensure relevance.
"""


wiki_instruction = """
You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:

1. **Parse the user query**:
   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.
   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".

2. **Fetch related keywords**:
   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.
   - From this list, select **up to 2–3 keywords** to fetch pages and index.  
   - Do not process more than 3 keywords, even if more are returned.

3. **Fetch and index pages**:
   - For **each keyword** in the list:
     a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page for that keyword.  
     b. Immediately call `search_tool.add_entry()` to chunk and index the page content.
     - Ensure `page_data` includes:
            - 'title' (str) — search keywords
            - 'content' (str) — content from the wiki of the keyword
            - 'url' (str or None) — url of the wikipdia. if missing, set to None
     - If a page with the same title already exists in the index, skip adding it again.
     - This step is **mandatory** for every keyword.
     - Do not wait until all pages are fetched — index each page immediately.
     

4. **Search the indexed content**:
   - Once **all keyword pages are indexed**, use the **original user query** as input to `search_tool.search(query)` to retrieve the most relevant chunks.

5. **Generate the answer**:
   - Compose your response **only from the retrieved indexed content**.
   - Do **not** use prior knowledge, assumptions, or external sources beyond the indexed Wikipedia content.
   - Summarize and present the answer clearly to the user.

**Important rules**:
- Only one main keyword should be parsed from the user query.  
- Every keyword returned by `get_keywords` **must** be fetched and indexed individually.  
- Call `add_entry` **immediately after fetching each page**.  
- Always search using the **original user query**, not the keywords.  
- Follow all steps strictly in order.

"""


wiki_search = WikiSearch()

index = AppendableIndex(
    text_fields=["title", "content"],
    keyword_fields=["title"]
)

search_tool = SearchTools(index)


class Reference(BaseModel):
    title: str
    url: str

class WikipediaResultArticle(BaseModel):
    found_answer: bool
    keyword: str
    content: str
    urls: list[Reference]
    # searches: list[str]

    def format_article(self):
        output = f"# {self.keyword.upper()}\n\n"
        output += f" {self.content}\n\n"
        
        output += "## References\n"
        for url in self.urls:
            
            output += f"- [{url.title}]({url.url})\n"
                
        return output


wiki_agent = Agent(
    name='Wikipeida',
    instructions=wiki_instruction,
    tools=[search_tool.search, search_tool.add_entry, wiki_search.get_keywords, wiki_search.get_keyword_page],
    model='gpt-4o-mini',
    output_type=WikipediaResultArticle
)
callback = NamedCallback(wiki_agent)

# %%
# Note: always make sure w have the clear doc string for each title

# %%
question = "where do capybaras live?"
question = "How do capybaras raise their young?"
question = "how do capybaras communicate within a group?"

result = await wiki_agent.run(
        user_prompt=question,
        event_stream_handler=callback,
    )
# Out:
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): get_keywords({"keyword":"capybaras"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Caviidae"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Capybara","content":"The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"},{"title":"Caviidae","content":"Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.","url":"https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"},{"title":"Hydrochoerus","content":"The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"how do capybaras communicate within a group?"})

# %%
print(result.output)
# Out:
# found_answer=True keyword='capybaras' content='Capybaras communicate through a variety of vocalizations, which include barks, chirps, whistles, huffs, and purrs. They are known to be highly social and can live in groups that may contain up to 100 individuals. Communication within these groups is important for establishing social bonds and hierarchical structures. Males often engage in vocalizations when asserting dominance or during specific social interactions, while females may vocalize to signal various states, such as being in estrus.' urls=[Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'), Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw')]

# %%
print(result.output.format_article())
# Out:
# # CAPYBARAS
#
#  Capybaras communicate through a variety of vocalizations, which include barks, chirps, whistles, huffs, and purrs. They are known to be highly social and can live in groups that may contain up to 100 individuals. Communication within these groups is important for establishing social bonds and hierarchical structures. Males often engage in vocalizations when asserting dominance or during specific social interactions, while females may vocalize to signal various states, such as being in estrus.
#
# ## References
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw)
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara&action=raw)

# %%
import json
from dataclasses import dataclass

@dataclass
class ToolCall:
    name: str
    args: dict

def get_tool_calls(result) -> list[ToolCall]:
    calls = []

    for m in result.new_messages():
        for p in m.parts:
            kind = p.part_kind
            if kind == 'tool-call':
                if p.tool_name == 'final_result':
                    continue
                call = ToolCall(
                    name=p.tool_name,
                    args=json.loads(p.args)
                )
                calls.append(call)

    return calls

get_tool_calls(result)
# Out:
# [ToolCall(name='search', args={'query': 'capybaras'}),
#  ToolCall(name='get_keywords', args={'keyword': 'capybaras'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Capybara'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Caviidae'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Hydrochoerus'}),
#  ToolCall(name='add_entry', args={'data': [{'title': 'Capybara', 'content': 'The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Caviidae', 'content': 'Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Hydrochoerus', 'content': 'The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}]}),
#  ToolCall(name='search', args={'query': 'how do capybaras communicate within a group?'})]

# %%
result.new_messages()
# Out:
# [ModelRequest(parts=[UserPromptPart(content='how do capybaras communicate within a group?', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 8, 983944, tzinfo=datetime.timezone.utc))], instructions='You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:\n\n1. **Parse the user query**:\n   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.\n   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".\n\n2. **Fetch related keywords**:\n   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.\n   - From this list, select **up to 2–3 keywords** to fetch pages and index.  \n   - Do not process more than 3 keywords, even if more are returned.\n\n3. **Fetch and index pages**:\n   - For **each keyword** in the list:\n     a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page for that keyword.  \n     b. Immediately call `search_tool.add_entry()` to chunk and index the page content.\n     - Ensure `page_data` includes:\n            - \'title\' (str) — search keywords\n            - \'content\' (str) — content from the wiki of the keyword\n            - \'url\' (str or None) — url of the wikipdia. if missing, set to None\n     - If a page with the same title already exists in the index, skip adding it again.\n     - This step is **mandatory** for every keyword.\n     - Do not wait until all pages are fetched — index each page immediately.\n\n\n4. **Search the indexed content**:\n   - Once **all keyword pages are indexed**, use the **original user query** as input to `search_tool.search(query)` to retrieve the most relevant chunks.\n\n5. **Generate the answer**:\n   - Compose your response **only from the retrieved indexed content**.\n   - Do **not** use prior knowledge, assumptions, or external sources beyond the indexed Wikipedia content.\n   - Summarize and present the answer clearly to the user.\n\n**Important rules**:\n- Only one main keyword should be parsed from the user query.  \n- Every keyword returned by `get_keywords` **must** be fetched and indexed individually.  \n- Call `add_entry` **immediately after fetching each page**.  \n- Always search using the **original user query**, not the keywords.  \n- Follow all steps strictly in order.'),
#  ModelResponse(parts=[ToolCallPart(tool_name='search', args='{"query":"capybaras"}', tool_call_id='call_V0wpW3fNEX7g5oys5GKl4iRB')], usage=RequestUsage(input_tokens=1163, cache_read_tokens=1024, output_tokens=16, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 9, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWV75LI42ixAei3adcS0Y1bu6RPL', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='search', content=[], tool_call_id='call_V0wpW3fNEX7g5oys5GKl4iRB', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 9, 949065, tzinfo=datetime.timezone.utc))], instructions='You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:\n\n1. **Parse the user query**:\n   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.\n   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".\n\n2. **Fetch related keywords**:\n   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.\n   - From this list, select **up to 2–3 keywords** to fetch pages and index.  \n   - Do not process more than 3 keywords, even if more are returned.\n\n3. **Fetch and index pages**:\n   - For **each keyword** in the list:\n     a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page for that keyword.  \n     b. Immediately call `search_tool.add_entry()` to chunk and index the page content.\n     - Ensure `page_data` includes:\n            - \'title\' (str) — search keywords\n            - \'content\' (str) — content from the wiki of the keyword\n            - \'url\' (str or None) — url of the wikipdia. if missing, set to None\n     - If a page with the same title already exists in the index, skip adding it again.\n     - This step is **mandatory** for every keyword.\n     - Do not wait until all pages are fetched — index each page immediately.\n\n\n4. **Search the indexed content**:\n   - Once **all keyword pages are indexed**, use the **original user query** as input to `search_tool.search(query)` to retrieve the most relevant chunks.\n\n5. **Generate the answer**:\n   - Compose your response **only from the retrieved indexed content**.\n   - Do **not** use prior knowledge, assumptions, or external sources beyond the indexed Wikipedia content.\n   - Summarize and present the answer clearly to the user.\n\n**Important rules**:\n- Only one main keyword should be parsed from the user query.  \n- Every keyword returned by `get_keywords` **must** be fetched and indexed individually.  \n- Call `add_entry` **immediately after fetching each page**.  \n- Always search using the **original user query**, not the keywords.  \n- Follow all steps strictly in order.'),
#  ModelResponse(parts=[ToolCallPart(tool_name='get_keywords', args='{"keyword":"capybaras"}', tool_call_id='call_gjGJq7vOPlN0gTkZkUgsnw9g')], usage=RequestUsage(input_tokens=1187, output_tokens=17, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 10, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWV8N40l54MLezEv7lQRuJyPmSDP', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='get_keywords', content=['Capybara', 'Lesser+capybara', 'Capybara+(disambiguation)', 'Caviidae', 'Capybara+Games', 'Kerodon', 'Hydrochoerus', 'Yuzu+bath', 'Izu+Shaboten+Zoo', 'Flow+(2024+film)'], tool_call_id='call_gjGJq7vOPlN0gTkZkUgsnw9g', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 11, 73874, tzinfo=datetime.timezone.utc))], instructions='You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:\n\n1. **Parse the user query**:\n   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.\n   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".\n\n2. **Fetch related keywords**:\n   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.\n   - From this list, select **up to 2–3 keywords** to fetch pages and index.  \n   - Do not process more than 3 keywords, even if more are returned.\n\n3. **Fetch and index pages**:\n   - For **each keyword** in the list:\n     a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page for that keyword.  \n     b. Immediately call `search_tool.add_entry()` to chunk and index the page content.\n     - Ensure `page_data` includes:\n            - \'title\' (str) — search keywords\n            - \'content\' (str) — content from the wiki of the keyword\n            - \'url\' (str or None) — url of the wikipdia. if missing, set to None\n     - If a page with the same title already exists in the index, skip adding it again.\n     - This step is **mandatory** for every keyword.\n     - Do not wait until all pages are fetched — index each page immediately.\n\n\n4. **Search the indexed content**:\n   - Once **all keyword pages are indexed**, use the **original user query** as input to `search_tool.search(query)` to retrieve the most relevant chunks.\n\n5. **Generate the answer**:\n   - Compose your response **only from the retrieved indexed content**.\n   - Do **not** use prior knowledge, assumptions, or external sources beyond the indexed Wikipedia content.\n   - Summarize and present the answer clearly to the user.\n\n**Important rules**:\n- Only one main keyword should be parsed from the user query.  \n- Every keyword returned by `get_keywords` **must** be fetched and indexed individually.  \n- Call `add_entry` **immediately after fetching each page**.  \n- Always search using the **original user query**, not the keywords.  \n- Follow all steps strictly in order.'),
#  ModelResponse(parts=[ToolCallPart(tool_name='get_keyword_page', args='{"search_keyword": "Capybara"}', tool_call_id='call_wjtQHILZHcdXGrSN94tP4LtS'), ToolCallPart(tool_name='get_keyword_page', args='{"search_keyword": "Caviidae"}', tool_call_id='call_uIyIGkPUtLGynlY7DF5j17Ee'), ToolCallPart(tool_name='get_keyword_page', args='{"search_keyword": "Hydrochoerus"}', tool_call_id='call_9jnGXQL0JOrnPlu2iQXm653r')], usage=RequestUsage(input_tokens=1273, cache_read_tokens=1152, output_tokens=71, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 11, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWV9JLbcLiLgMq3bY0zQ6Gs45l0Y', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='get_keyword_page', content=[{'title': 'Capybara', 'content': '{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name="iucn status 19 November 2021">{{cite iucn |author=Reid, F. |date=2016 |title=\'\'Hydrochoerus hydrochaeris\'\' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petrópolis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petrópolis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = \'\'Sus hydrochaeris\'\' {{small|Linnaeus,&nbsp;1766}}\n}}\n\nThe \'\'\'capybara\'\'\'{{efn | Also referred as \'\'\'capivara\'\'\' (in Brazil), \'\'\'capiguara\'\'\' (in Bolivia), \'\'\'chigüire\'\'\', \'\'\'chigüiro\'\'\', or \'\'\'fercho\'\'\' (in Colombia and Venezuela), \'\'\'carpincho\'\'\' (in Argentina, Paraguay and Uruguay) and \'\'\'ronsoco\'\'\' (in Peru).}} or \'\'\'greater capybara\'\'\' (\'\'\'\'\'Hydrochoerus hydrochaeris\'\'\'\'\') is the largest living rodent,<ref>{{Cite web | author= Basic Biology | date= 2015 | title= Rodents | url= https://basicbiology.net/animal/mammals/rodents}}</ref> native to [[South America]]. It is a member of the genus \'\'[[Hydrochoerus]]\'\'. Its close relatives include\n[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. The capybara is hunted for its meat and hide and also for grease from its thick fatty skin.<ref>[http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ Capybara (\'\'Hydrochoerus hydrochaeris\'\')] {{Webarchive|url=https://web.archive.org/web/20120103075238/http://www.arkive.org/capybara/hydrochoerus-hydrochaeris/ |date=2012-01-03 }}. ARKive.org</ref>\n\n==Etymology==\nIts common name is derived from [[Tupi language|Tupi]] {{lang|tpn|ka\'apiûara}}, a complex agglutination of {{lang|tpn|kaá}} (leaf) + {{lang|tpn|píi}} (slender) + {{lang|tpn|ú}} (eat) + {{lang|tpn|ara}} (a suffix for agent nouns), meaning "one who eats slender leaves", or "grass-eater".<ref>Ferreira, A. B. H. (1986) \'\'[[Novo Dicionário da Língua Portuguesa]]\'\', 2nd ed., Rio de Janeiro: Nova Fronteira, p.344</ref> The [[genus name]], \'\'hydrochoerus\'\', comes from [[Ancient Greek|Greek]] {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χοῖρος}} (\'\'{{lang|grc-Latn|choíros}}\'\' "pig, hog") and the species name, \'\'hydrochaeris\'\', comes from Greek {{lang|grc|ὕδωρ}} (\'\'{{lang|grc-Latn|hýdor}}\'\' "water") and {{lang|grc|χαίρω}} (\'\'{{lang|grc-Latn|chairo}}\'\' "feel happy, enjoy").<ref name=msw3>{{MSW3 Woods|id=13400218|page=1556}}</ref><ref name="inDarwin">{{Cite book | last=Darwin | first=Charles R. | author-link =Charles Darwin| year=1839 | title=Narrative of the surveying voyages of His Majesty\'s Ships Adventure and Beagle between the years 1826 and 1836, describing their examination of the southern shores of South America, and the Beagle\'s circumnavigation of the globe. Journal and remarks. 1832–1836. | title-link =The Voyage of the Beagle| place =London | publisher =[[Henry Colburn]] | page=619}}\n* In page 57, Darwin says "The largest gnawing animal in the world, the \'\'Hydrochærus Capybara\'\' (the water-hog), is here also common."\n* See it a ...
#  ModelResponse(parts=[ToolCallPart(tool_name='add_entry', args='{"data":[{"title":"Capybara","content":"The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"},{"title":"Caviidae","content":"Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.","url":"https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"},{"title":"Hydrochoerus","content":"The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]}', tool_call_id='call_hJP6JxryRb6wdmXqO0Gx77nu')], usage=RequestUsage(input_tokens=17259, cache_read_tokens=1280, output_tokens=534, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 13, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWVBTK8T8stGZl55osNCJcto3T9p', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='add_entry', content=[{'title': 'Capybara', 'content': 'The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Capybara', 'content': 'wn to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Capybara', 'content': ' general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Caviidae', 'content': 'Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Caviidae', 'content': ' form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Hydrochoerus', 'content': 'The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}, {'title': 'Hydrochoerus', 'content': ' in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}], tool_call_id='call_hJP6JxryRb6wdmXqO0Gx77nu', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 28, 687041, tzinfo=datetime.timezone.utc))], instructions='You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:\n\n1. **Parse the user query**:\n   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.\n   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".\n\n2. **Fetch related keywords**:\n   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.\n   - From this list, select **up to 2–3 keywords** to fetch pages and index.  \n   - Do not process more than 3 keywords, even if more are returned.\n\n3. **Fetch and index pages**:\n   -  ...
#  ModelResponse(parts=[ToolCallPart(tool_name='search', args='{"query":"how do capybaras communicate within a group?"}', tool_call_id='call_2MVEn8y5nVOfFylQLF19z3Ku')], usage=RequestUsage(input_tokens=18506, cache_read_tokens=17664, output_tokens=23, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 29, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWVRTpuFQbDPPDCQBG8pIFzXIwPA', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='search', content=[{'title': 'Hydrochoerus', 'content': 'The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}, {'title': 'Caviidae', 'content': 'Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Capybara', 'content': 'wn to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Capybara', 'content': ' general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Capybara', 'content': 'The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}], tool_call_id='call_2MVEn8y5nVOfFylQLF19z3Ku', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 29, 848047, tzinfo=datetime.timezone.utc))], instructions='You are an intelligent assistant designed to answer user questions using Wikipedia as your **sole source**. Follow this workflow **exactly**, without skipping any steps:\n\n1. **Parse the user query**:\n   - Extract **only one main keyword** from the user query. This will serve as the primary topic for your search.\n   - Example: For "How do capybaras communicate within a group?", the main keyword = "capybaras".\n\n2. **Fetch related keywords**:\n   - Call `wiki_search.get_keywords(main_keyword)` to retrieve a list of related keywords.\n   - From this list, select **up to 2–3 keywords** to fetch pages and index.  \n   - Do not process more than 3 keywords, even if more are returned.\n\n3. **Fetch and index pages**:\n   - For **each keyword** in the list:\n     a. Call `wiki_search.get_keyword_page(keyword)` to fetch the Wikipedia page for that keyword.  \n     b. Immediately call `search_tool.add_entry()` to chunk and index the page content.\n     - Ensure `page_data` includes:\n            - \'title\' (str) — search keywords\n            - \'content\' (str) — content from the wiki of the keyword\n            - \'url\' (str or None) — url of the wikipdia. if missing, set to None\n     - If a page with the same title already exists in the index, skip adding it again.\ ...
#  ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"found_answer":true,"keyword":"capybaras","content":"Capybaras communicate through a variety of vocalizations, which include barks, chirps, whistles, huffs, and purrs. They are known to be highly social and can live in groups that may contain up to 100 individuals. Communication within these groups is important for establishing social bonds and hierarchical structures. Males often engage in vocalizations when asserting dominance or during specific social interactions, while females may vocalize to signal various states, such as being in estrus.","urls":[{"title":"Hydrochoerus","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"},{"title":"Capybara","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]}', tool_call_id='call_noBkDBZcFQbIXMHWTOzjrI7P')], usage=RequestUsage(input_tokens=19119, cache_read_tokens=1152, output_tokens=182, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 30, tzinfo=TzInfo(0)), provider_name='openai', provider_details={'finish_reason': 'tool_calls'}, provider_response_id='chatcmpl-CZWVStYxBJrqo5XQJxWqfZksBltc1', finish_reason='tool_call'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='call_noBkDBZcFQbIXMHWTOzjrI7P', timestamp=datetime.datetime(2025, 11, 8, 6, 14, 34, 72540, tzinfo=datetime.timezone.utc))])]

# %%
get_tool_calls(result)
# Out:
# [ToolCall(name='search', args={'query': 'capybaras'}),
#  ToolCall(name='get_keywords', args={'keyword': 'capybaras'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Capybara'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Caviidae'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Hydrochoerus'}),
#  ToolCall(name='add_entry', args={'data': [{'title': 'Capybara', 'content': 'The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Caviidae', 'content': 'Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Hydrochoerus', 'content': 'The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}]}),
#  ToolCall(name='search', args={'query': 'how do capybaras communicate within a group?'})]

# %%
tool_calls = get_tool_calls(result)

call_get_keywords = False
for tool in tool_calls:
    if tool.name == 'get_keywords':
        call_get_keywords = True

# %%
tool_calls
# Out:
# [ToolCall(name='search', args={'query': 'capybaras'}),
#  ToolCall(name='get_keywords', args={'keyword': 'capybaras'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Capybara'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Caviidae'}),
#  ToolCall(name='get_keyword_page', args={'search_keyword': 'Hydrochoerus'}),
#  ToolCall(name='add_entry', args={'data': [{'title': 'Capybara', 'content': 'The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of around 10–20 individuals, with two to four adult males, four to seven adult females, and the remainder juveniles. Capybara groups can consist of as many as 50 or 100 individuals during the dry season when the animals gather around available water sources. Males establish social bonds, dominance, or general group consensus.', 'url': 'https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'}, {'title': 'Caviidae', 'content': 'Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in groups with each having a dominant male and a number of females, subordinate males, and juveniles, exemplifying their social structure.', 'url': 'https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'}, {'title': 'Hydrochoerus', 'content': 'The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.', 'url': 'https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'}]}),
#  ToolCall(name='search', args={'query': 'how do capybaras communicate within a group?'})]

# %%
count = sum(1 for call in tool_calls if call.name == "get_keyword_page")
count
# Out:
# 3

# %%
@dataclass
class ToolCall:
    name: str
    args: dict


def get_tool_calls(result) -> list[ToolCall]:
    calls = []

    for m in result.new_messages():
        for p in m.parts:
            kind = p.part_kind
            if kind == 'tool-call':
                if p.tool_name == 'final_result':
                    continue
                call = ToolCall(
                    name=p.tool_name,
                    args=json.loads(p.args)
                )
                calls.append(call)

    return calls

# %%
len(result.output.urls)
# Out:
# 2

# %%
print(result.output.format_article())
# Out:
# # CAPYBARAS
#
#  Capybaras communicate through a variety of vocalizations, which include barks, chirps, whistles, huffs, and purrs. They are known to be highly social and can live in groups that may contain up to 100 individuals. Communication within these groups is important for establishing social bonds and hierarchical structures. Males often engage in vocalizations when asserting dominance or during specific social interactions, while females may vocalize to signal various states, such as being in estrus.
#
# ## References
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw)
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara&action=raw)

# %%
question = [
     #  "where do capybaras live?",
     "how do capybaras communicate within a group?",
     "How have capybaras adapted physically and behaviorally to living near water?",
     "What do capybaras eat",
     "What strategies do capybaras use to stay safe from predators?",
     # "Which animals prey on capybaras in the wild, and what strategies do capybaras use to avoid them?"
     "Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?",
     "How do capybaras raise their young",
     "What role do capybaras play in their ecosystems?",
     "How have humans affected capybara populations?",
     "Why have capybaras become such popular animals on social media?",
     "Where do capybaras orginate from?"
     ]


# How can we correctly parse the keyword?
# sarch which documern

# %%
for q in question:
    print(q)
# Out:
# how do capybaras communicate within a group?
# How have capybaras adapted physically and behaviorally to living near water?
# What do capybaras eat
# What strategies do capybaras use to stay safe from predators?
# Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?
# How do capybaras raise their young
# What role do capybaras play in their ecosystems?
# How have humans affected capybara populations?
# Why have capybaras become such popular animals on social media?
# Where do capybaras orginate from?

# %%
answer = {}


for q in question:
    result = await wiki_agent.run(
            user_prompt=q,
            event_stream_handler=callback,
        )
    
    answer[q] = result.output
# Out:
# TOOL CALL (Wikipeida): get_keywords({"keyword":"capybaras"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Caviidae"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Capybara","content":"{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name=\"iucn status 19 November 2021\">{{cite iucn |author=Reid, F. |date=2016 |title=''Hydrochoerus hydrochaeris'' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hydrochoeris hydrochaeris in Brazil in Petr\u0000d3polis, Rio de Janeiro, Brazil 09.jpg\n| image_caption     = In [[Petr\u0000d3polis]], Brazil\n| genus             = Hydrochoerus\n| species           = hydrochaeris\n| authority         = ([[Carl Linnaeus|Linnaeus]], [[12th edition of Systema Naturae|1766]])\n| range_map         = Capybara range.svg\n| range_map_caption = Native range\n| synonyms          = ''Sus hydrochaeris'' {{small|Linnaeus,&nbsp;1766}}\n}}\n\nThe '''capybara'''{{efn | Also referred as '''capivara''' (in Brazil), '''capiguara''' (in Bolivia), '''chig\u0000cire''', '''chig\u0000ciro''' (in Colombia and Venezuela), '''carpincho''' (in Argentina, Paraguay and Uruguay) and '''ronsoco''' (in Peru).}} or '''greater capybara''' ('''''Hydrochoerus hydrochaeris''''') is the largest living rodent, native to [[South America]]. It is a member of the genus ''[[Hydrochoerus]]''. Its close relatives include[[Cavia|guinea pig]]s and [[Kerodon|rock cavies]], and it is more distantly related to the [[agouti]], the [[chinchilla]], and the [[nutria]]. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10\u0011\u0014 individuals. Capybaras communicate using barks, chirps, whistles, huffs, and purrs, and males establish social bonds, dominance, or general group consensus.","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}],"chunk_size":500,"overlap":100})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Caviidae","content":"{{Short description|Family of rodents that includes the domestic guinea pig}}\n{{Redirect|Cavy|the animal commonly referred to as \"cavy\"|guinea pig|possible confusion|Kavi (disambiguation){{!}}Kavi}}\n{{Automatic taxobox\n| fossil_range = {{Fossil range|Middle Miocene|Holocene}}\n| image = Hydrochoeris hydrochaeris in Brazil in Petr\u0000d3polis, Rio de Janeiro, Brazil 09.jpg\n| image_caption = [[Capybara]]\n| taxon = Caviidae\n| authority = [[Johann Fischer von Waldheim|Fischer von Waldheim]], 1818\n| subdivision_ranks = Subfamilies\n| subdivision = \n&nbsp;[[Caviinae]]<br/>\n&nbsp;[[Dolichotinae]]<br/>\n&nbsp;[[Hydrochoerinae]]\n}}\n\n'''Caviidae''', the '''cavy''' [[family (biology)|family]], is composed of [[rodent]]s native to [[South America]] and includes the [[domestic guinea pig]], wild cavies, and the largest living rodent, the [[capybara]]. They are found across South America in open areas from moist [[savanna]] to [[thorn forest]]s or [[scrubland|scrub]] [[desert]]. This family of rodents has fewer members than most [[Rodent#Standard classification|other rodent families]], with 19 species in seven genera in three subfamilies.\n\n==Characteristics==\n[[File:Cavy (1).jpg|thumb|left|Guinea pig skull on top of a capybara skull]] \nWith the exception of the [[Mara (mammal)|mara]]s, which have a more [[rabbit]]-like appearance, caviids have short, heavy bodies and large heads. Most have no visible [[tail]]s. They range in size from the smaller cavies at 22&nbsp;cm in body length, and 300&nbsp;grams in weight, up to the [[capybara]], the largest of all rodents at 106 to 134&nbsp;cm in length, and body weights of 35 to 66 kilograms. Even larger forms existed in the [[Pliocene]], such as ''[[Phugatherium]]'', which was about the size of a [[tapir]].<ref name=MamEv>{{cite book |author1=Savage, RJG |author2=Long, MR |year=1986 |title= Mammal Evolution: an illustrated guide|url=https://archive.org/details/mammalevolutioni0000sava |url-access=registration |publisher= Facts on File|location=New York|pages= [https://archive.org/details/mammalevolutioni0000sava/page/125 125\u0011\u0012 126]|isbn= 0-8160-1194-X}}</ref>\n\nThey are [[herbivore]]s, eating tough grasses or softer leaves, depending on species. The [[dentition|dental formula]] is similar to that of various other rodents: {{DentalFormula|upper=1.0.1.3|lower=1.0.1.3}}. Females give birth to two or three furred and active young after a [[gestation]] period of 50 to 90 days in most species, or 150 days in the capybara. In most species, they are sexually mature within a few months of birth, although in capybaras, maturity is not reached until around 18 months.<ref name=EoM/>\n\nSocial organisation varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are [[Monogamy in animals|monogamous]], and form temporary colonial [[Cr\u0000e8che (zoology)|cr\u0000e8ches]] to care for the young of multiple mothers. Capybaras live in groups of around 10 individuals, and sometimes many more, each with a single dominant male, and a number of females, subordinate males, and juveniles.<ref name=EoM>{{cite book |editor=Macdonald, D. |author1=Herrera, E. |author2=Lacher, T.E. |author3=Macdonald, D. |author4=Taber, A.B. |year=1984 |title=The Encyclopedia of Mammals |publisher=Facts on File |location=New York |pages=[https://archive.org/details/encyclopediaofma00mals_0/page/690 690\u0011\u0012 699]|isbn=0-87196-871-1 |url-access=registration |url=https://archive.org/details/encyclopediaofma00mals_0/page/690 }}</ref>\n\n==Classification==\n{{further|List of caviids}}\n\nThe family '''Caviidae''' is a sister group to the family [[Dasyproctidae]], both of which are members of the superfamily Cavioidea.<ref>{{Cite journal|url = http://kit.eimb.ru/PDF/Veniaminova_07_G_en.pdf|title = Phylogeny o ...
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Hydrochoerus","content":"{{Short description|Genus of rodents}}\n{{automatic taxobox\n| taxon = Hydrochoerus\n| fossil_range = [[Pliocene]] - [[Holocene|Recent]]<br>~{{fossil range|3.6|0}}\n| image = Esteros Del Ibera, Corrientes, Argentina, 3rd. Jan. 2011 - Flickr - PhillipC (2).jpg\n| image_caption = ''H. hydrochaeris'' with a [[cattle tyrant]] on its back\n| authority = [[Mathurin Jacques Brisson|Brisson]], 1762\n| type_species = ''[[Hydrochoerus hydrochaeris|Sus hydrochaeris]]''<ref name=msw3/>\n| type_species_authority = [[Carl Linnaeus|Linnaeus]], 1766\n| subdivision_ranks = [[Species]]\n| subdivision = [[extinct|\u0000]] ''[[Hydrochoerus ballesterensis|H. ballesterensis]]''<br>\n[[extinct|\u0000]] ''[[Hydrochoerus gaylordi|H. gaylordi]]''<br>\n[[extinct|\u0000]] ''[[Hydrochoerus hesperotiganites|H. hesperotiganites]]''<br>\n''[[Hydrochoerus hydrochaeris|H. hydrochaeris]]''<br>\n''[[Hydrochoerus isthmius|H. isthmius]]''\n| range_map = Capybara-ranges.png\n| range_map_upright = 0.9\n| range_map_caption = Ranges of [[capybara]] (green) and [[lesser capybara]] (red)\n}}\n\nThe genus '''''Hydrochoerus''''' contains two living and three extinct species of rodents from [[South America]], the Caribbean island of [[Grenada]], [[California]] and [[Panama]].<ref name=msw3>{{MSW3 Woods|id=13400217}}</ref> Capybaras are the largest living rodents in the world. The [[genus name]] is derived from [[Ancient Greek]] [[wikt:\u0000|h\u0000dor]], meaning \"water\", and [[wikt:\u00000|kho\u00000ros]], meaning \"pig\".\n\n== Characteristics ==\nCapybaras are [[semiaquatic]], found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Adults weigh up to {{convert|65|kg|lb|abbr=on}}. The [[gestation period]] is 130\u0011\u0012 150 days, with two to eight (most commonly four) young born to females.\n\n== Behavior ==\nCapybaras are highly social, living in groups of up to 100 and communicating through a variety of [[Animal communication#Auditory|vocalizations]].<ref name=Rowe2002>Rowe and Honeycutt, 2002</ref> Breeding is [[polygyny in animals|polygynous]], with males forming [[Harem (zoology)|harems]].","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}],"chunk_size":500,"overlap":100})
# TOOL CALL (Wikipeida): search({"query":"How do capybaras communicate within a group?"})
# TOOL CALL (Wikipeida): search({"query":"How have capybaras adapted physically and behaviorally to living near water?"})
# TOOL CALL (Wikipeida): get_keywords({"keyword": "capybaras"})
# TOOL CALL (Wikipeida): get_keywords({"keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): get_keywords({"keyword": "semiaquatic"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Semiaquatic"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious.", "url": "https://en.wikipedia.org/w/index.php?title=Capybara"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "Capybaras are the largest living rodents in the world. The genus name is derived from Ancient Greek \"húdor\", meaning \"water\", and \"khoéros\", meaning \"pig\". Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Adults weigh up to 65 kg. The gestation period is 130–150 days, with two to eight (most commonly four) young born to females.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Semiaquatic", "content": "In biology, being semiaquatic refers to various macroorganisms that live regularly in both aquatic and terrestrial environments. Semiaquatic animals include some amphibians, some reptiles, and some mammals, including capybaras. They have adaptations for life in and near water, such as webbed feet and excellent swimming abilities.", "url": "https://en.wikipedia.org/w/index.php?title=Semiaquatic"}]})
# TOOL CALL (Wikipeida): search({"query":"How have capybaras adapted physically and behaviorally to living near water?"})
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America.", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara.", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"What do capybaras eat"})
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"What strategies do capybaras use to stay safe from predators?"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "{{Short description|Largest species of rodents}}\n{{Other uses}}\n{{Good article}}\n{{pp|small=yes}}\n{{Use dmy dates|date=July 2022}}\n{{Speciesbox\n| status            = LC\n| status_system     = IUCN3.1\n| status_ref        = <ref name=\"iucn status 19 November 2021\">{{cite iucn |author=Reid, F. |date=2016 |title=''Hydrochoerus hydrochaeris'' |volume=2016 |article-number=e.T10300A22190005 |doi=10.2305/IUCN.UK.2016-2.RLTS.T10300A22190005.en |access-date=19 November 2021}}</ref>\n| image             = Hy", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses. Capybaras communicate through a variety of vocalizations. Breeding is polygynous, with males forming harems and living in groups that can include many individuals, enhancing their social interaction.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Social organisation varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in large and socially complex groups, which facilitates interactions with various other species.", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "Capybaras are highly social, living in groups of up to 100 and communicating through a variety of vocalizations. Their social nature, along with their ability to coexist in diverse habitats including those shared with other animals, makes them seem friendly and chill. They are often seen interacting peacefully with different species, which adds to this perception.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): get_keywords({"keyword":"capybaras"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Caviidae"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Capybara","content":"The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious and often establish social bonds within their groups.","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"},{"title":"Caviidae","content":"Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Capybaras live in groups of around 10 individuals, and social organization can vary significantly, often establishing social hierarchies with dominant males leading.","url":"https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"},{"title":"Hydrochoerus","content":"The genus Hydrochoerus contains two living species of rodents from South America, the capybara being the largest. Capybaras are semiaquatic and social animals, typically found near water bodies. They breed polygynously, usually producing two to eight young after a gestation period of 130–150 days, and form strong social groups.","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"How do capybaras raise their young"})
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "Capybaras are highly social, living in groups of up to 100 and communicating through a variety of vocalizations. Their social nature, along with their ability to coexist in diverse habitats including those shared with other animals, makes them seem friendly and chill. They are often seen interacting peacefully with different species, which adds to this perception.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Social organisation varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to live in large and socially complex groups, which facilitates interactions with various other species.", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"What role do capybaras play in their ecosystems?"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): get_keywords({"keyword":"capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Caviidae"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Capybara","content":"The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus and its close relatives include guinea pigs and rock cavies. Capybaras typically inhabit savannas and dense forests, living near bodies of water in groups of 10–20 individuals, but can sometimes be found in larger groups. They are highly social and are known for their ability to communicate with each other through various vocalizations. They are also hunted for their meat and hide, which has led to reductions in their population in certain areas due to hunting and habitat competition with livestock. However, they breed rapidly, and in many regions, their population remains stable.","url":"https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}],"chunk_size":500,"overlap":100})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Caviidae","content":"Caviidae, the cavy family, includes rodents native to South America, like the domestic guinea pig and the largest living rodent, the capybara. This family comprises 19 species in seven genera. Caviids are primarily herbivores, with diets generally consisting of tough grasses or softer leaves.","url":"https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}],"chunk_size":500,"overlap":100})
# TOOL CALL (Wikipeida): add_entry({"data":[{"title":"Hydrochoerus","content":"The genus Hydrochoerus includes the capybara and the lesser capybara, both native to South America. Capybaras are the largest living rodents and are semiaquatic, inhabiting environments near lakes, rivers, and swamps. They are highly social animals with diets focused on grasses and communicate through various vocalizations. The genus name derives from Greek, meaning \"water pig.\"","url":"https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}],"chunk_size":500,"overlap":100})
# TOOL CALL (Wikipeida): search({"query":"How have humans affected capybara populations?"})
# TOOL CALL (Wikipeida): search({"query":"capybaras"})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Capybara", "content": "The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It is a member of the genus Hydrochoerus. The capybara inhabits savannas and dense forests, and lives near bodies of water. It is a highly social species and can be found in groups as large as one hundred individuals, but usually live in groups of 10–20 individuals. Capybaras are known to be gregarious. While they sometimes live solitarily, they are more commonly found in groups of", "url": "https://en.wikipedia.org/w/index.php?title=Capybara&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Hydrochoerus", "content": "The genus Hydrochoerus contains two living and three extinct species of rodents from South America. Capybaras are the largest living rodents in the world. Capybaras are semiaquatic, found in and near lakes, rivers, swamps, and flooded savanna. Their diets are dominated by grasses.", "url": "https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw"}]})
# TOOL CALL (Wikipeida): add_entry({"data": [{"title": "Caviidae", "content": "Caviidae, the cavy family, is composed of rodents native to South America and includes the domestic guinea pig, wild cavies, and the largest living rodent, the capybara. Social organization varies widely among the group. Many cavies are promiscuous, forming no long-lasting social groups, although, in some species, males maintain harems of two or more females. In contrast, maras are monogamous, and form temporary colonial crèches to care for the young of multiple mothers. Capybaras are known to l", "url": "https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw"}]})
# TOOL CALL (Wikipeida): search({"query":"Why have capybaras become such popular animals on social media?"})
# TOOL CALL (Wikipeida): get_keywords({"keyword":"capybaras"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Capybara"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Hydrochoerus"})
# TOOL CALL (Wikipeida): get_keyword_page({"search_keyword": "Caviidae"})
# TOOL CALL (Wikipeida): search({"query":"Where do capybaras originate from?"})

# %%
answer
# Out:
# {'how do capybaras communicate within a group?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras communicate using barks, chirps, whistles, huffs, and purrs, which facilitate social interaction within their groups. They are highly social animals, typically living in groups of 10 to 20 individuals, but can gather in larger numbers, sometimes up to 100 during certain conditions, such as the dry season around water sources. Males establish social bonds within these groups, expressing dominance and consensus which contributes to their complex social structures.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'), Reference(title='Caviidae', url='https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'), Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw')]),
#  'How have capybaras adapted physically and behaviorally to living near water?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras, or greater capybaras (Hydrochoerus hydrochaeris), are the largest living rodents and are native to South America. They have adapted physically and behaviorally to their semiaquatic lifestyle, living near lakes, rivers, swamps, and in flooded savannas. Their physical adaptations include a heavy, barrel-shaped body with slightly webbed feet that aid in swimming. Capybaras are also known to be superb swimmers and can hold their breath underwater for several minutes, using this ability to evade predators. Their eyes, ears, and nostrils are positioned on the top of the head, allowing them to see and breathe while submerged.\n\nBehaviorally, capybaras are highly social animals, often found in groups of 10–20, but can also gather in larger groups of up to one hundred during the dry season when they congregate around water sources. They communicate through various vocalizations and exhibit social behaviors such as grooming and establishing dominance within their groups. Additionally, their diet consists mainly of grasses, which they graze near water, showcasing their adaptation to the environment they inhabit. Capybaras breed in water and their gestation period is about 130–150 days, typically resulting in litters of two to eight young. These adaptations facilitate their survival in habitats rich in water resources.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara'), Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus')]),
#  'What do capybaras eat': WikipediaResultArticle(found_answer=True, keyword='capybaras', content="Capybaras' diets are dominated by grasses. They are herbivores, primarily feeding on aquatic plants, grasses, and some fruits. Being semiaquatic, they inhabit regions near water bodies which provide access to their main food sources.", urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw')]),
#  'What strategies do capybaras use to stay safe from predators?': WikipediaResultArticle(found_answer=False, keyword='capybaras', content='The indexed content did not provide specific strategies capybaras use to stay safe from predators. However, it yields general information on their social structure and behaviors which can indirectly imply safety. Capybaras are social animals found in groups of up to one hundred individuals, with a typical group size of 10-20. Living in numbers helps provide safety in numbers against predators.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw')]),
#  'Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras are often considered friendly or chill animals due to their highly social nature. They live in groups of up to 100 and communicate through a variety of vocalizations, facilitating interactions with one another. Their large, socially complex groups allow them to coexist and interact peacefully with various other species, which contributes to this perception of them being friendly.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'), Reference(title='Caviidae', url='https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'), Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw')]),
#  'How do capybaras raise their young': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras breed polygynously, usually producing a litter of two to eight young after a gestation period of 130 to 150 days. The young are born active and furred and join the group within several hours of being born. They are able to start eating grass within a week but continue to suckle from any nursing female in the group until they are weaned at around 16 weeks. This communal nursing behavior, known as alloparenting, allows for multiple females in the group to care for the young.', urls=[Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw'), Reference(title='Caviidae', url='https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw')]),
#  'What role do capybaras play in their ecosystems?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras play a significant role in their ecosystems as they inhabit savannas and dense forests and live near bodies of water. They are a highly social species known to thrive in groups usually consisting of 10–20 individuals but can range up to 100. Their social nature allows them to interact peacefully with various other species, enhancing the biodiversity of their habitat. As they are herbivores, their diet, primarily consisting of grasses, affects the vegetation structure in their environment, potentially influencing other plant and animal species. Additionally, their presence can attract a variety of other wildlife that share their aquatic habitats. Thus, capybaras contribute to maintaining ecological balance in their habitats.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'), Reference(title='Caviidae', url='https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw')]),
#  'How have humans affected capybara populations?': WikipediaResultArticle(found_answer=True, keyword='capybara', content='Capybaras are not considered a threatened species; their population is stable throughout most of their South American range, but in some areas, hunting has reduced their numbers. They are hunted for their meat and pelts, and in some cases, they are also killed by humans who view them as competition for livestock. In regions where they are farmed, this practice can help protect their wetland habitats. Despite the hunting pressures, capybaras can breed rapidly, which aids their survival. Additionally, they have adapted well to urbanization in South America, often being seen in parks and zoos, where they can live longer due to better living conditions.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw')]),
#  'Why have capybaras become such popular animals on social media?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='Capybaras are highly social animals, typically living in groups of 10–20, and can even form groups of up to 100 individuals. Their gregarious nature and friendly demeanor contribute to their popularity on social media, where they are often depicted interacting playfully with other species. This ability to coexist peacefully, along with their unique vocalizations and semiaquatic lifestyle, resonates with audiences, making them appear charming and approachable, which enhances their visibility and popularity online.', urls=[Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw')]),
#  'Where do capybaras orginate from?': WikipediaResultArticle(found_answer=True, keyword='capybaras', content='The capybara or greater capybara (Hydrochoerus hydrochaeris) is the largest living rodent, native to South America. It inhabits savannas and dense forests and lives near bodies of water. Capybaras are highly social animals that can be found in groups ranging from 10 to as many as 100 individuals. The genus Hydrochoerus includes two living species, both of which are native to regions in South America.', urls=[Reference(title='Capybara', url='https://en.wikipedia.org/w/index.php?title=Capybara&action=raw'), Reference(title='Caviidae', url='https://en.wikipedia.org/w/index.php?title=Caviidae&action=raw'), Reference(title='Hydrochoerus', url='https://en.wikipedia.org/w/index.php?title=Hydrochoerus&action=raw')])}

# %%
# what changes i make

# make sure the description and the doc string match the fu
#

# %%
for q in question:
    print(q)
# Out:
# how do capybaras communicate within a group?
# How have capybaras adapted physically and behaviorally to living near water?
# What do capybaras eat
# What strategies do capybaras use to stay safe from predators?
# Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?
# How do capybaras raise their young
# What role do capybaras play in their ecosystems?
# How have humans affected capybara populations?
# Why have capybaras become such popular animals on social media?
# Where do capybaras orginate from?

# %%
import pandas as pd

pd.DataFrame(final_result)
# Out:
#                                             question  found_answer  \
# 0       how do capybaras communicate within a group?          True
# 1  How have capybaras adapted physically and beha...          True
# 2                              What do capybaras eat          True
# 3  What strategies do capybaras use to stay safe ...          True
# 4  Why are capybaras often considered “friendly” ...          True
# 5                 How do capybaras raise their young          True
# 6   What role do capybaras play in their ecosystems?          True
# 7     How have humans affected capybara populations?          True
# 8  Why have capybaras become such popular animals...         False
# 9                  Where do capybaras orginate from?          True
#
#                                              content  reference_url
# 0  # CAPYBARAS\n\n Capybaras are highly social an...           True
# 1  # CAPYBARAS\n\n Capybaras, the largest living ...           True
# 2  # CAPYBARAS\n\n Capybaras are herbivores, prim...           True
# 3  # CAPYBARAS\n\n Capybaras employ several strat...           True
# 4  # CAPYBARAS\n\n Capybaras are often considered...           True
# 5  # CAPYBARAS\n\n Capybaras, which are part of t...           True
# 6  # CAPYBARAS\n\n Capybaras play a key role in t...           True
# 7  # CAPYBARAS\n\n Capybaras are not considered a...           True
# 8  # CAPYBARAS\n\n The capybara is known for bein...           True
# 9  # CAPYBARAS\n\n The capybara is the largest li...           True

# %%
final_result = []
for k, v in answer.items():
    temp = {}
    temp['question'] = k
    temp['found_answer'] = v.found_answer
    if len(v.urls) > 0:
        temp['reference_url'] = True
    else:
        temp['reference_url'] = False
    temp['content'] = v.format_article()
    final_result.append(temp)

    # if k == 'Why have capybaras become such popular animals on social media?':
    print(k)

    print(v.found_answer)
    print(v.format_article())
    
    print('----\n')
# Out:
# how do capybaras communicate within a group?
# True
# # CAPYBARAS
#
#  Capybaras are highly social animals typically living in groups of 10 to 20 individuals, but they can gather in larger groups of up to one hundred during certain times. They communicate effectively within their groups using a variety of vocalizations, including barks, chirps, whistles, huffs, and purrs. This communication plays an essential role in their social organization and interactions.
#
# ## References
# - [Capybara](https://en.wikipedia.org/wiki/Capybara)
# - [Caviidae](https://en.wikipedia.org/wiki/Caviidae)
#
# ----
#
# How have capybaras adapted physically and behaviorally to living near water?
# True
# # CAPYBARAS
#
#  Capybaras, the largest living rodents native to South America, have developed several physical and behavioral adaptations for their semiaquatic lifestyle. They typically inhabit savannas and dense forests near bodies of water, which is essential for their social behaviors and feeding. Physically, capybaras possess slightly webbed feet, enabling them to swim effectively. Their blunt muzzles and nostrils positioned at the top of their heads facilitate swimming and foraging in aquatic environments. They are excellent swimmers and can hold their breath underwater for up to five minutes.
#
# Behaviorally, capybaras are highly social animals, often living in groups of about 10 to 20 individuals, and can gather in larger numbers during the dry season around water sources. Their social organization and group living not only help with communication among individuals but also provide safety from predators. Their diet primarily consists of grasses and aquatic plants, which they can access easily due to their proximity to water. Overall, these adaptations are crucial for their survival and effective functioning in their natural habitat.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara)
# - [Caviidae](https://en.wikipedia.org/w/index.php?title=Caviidae)
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus)
#
# ----
#
# What do capybaras eat
# True
# # CAPYBARAS
#
#  Capybaras are herbivores, primarily grazing on grasses and aquatic plants. They also eat fruits and tree bark. They are very selective feeders, often choosing specific plants and may switch to eating more abundant reeds during dry seasons when their preferred grasses are less available.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara&action=raw)
#
# ----
#
# What strategies do capybaras use to stay safe from predators?
# True
# # CAPYBARAS
#
#  Capybaras employ several strategies to stay safe from predators, primarily through their social structure and physical adaptations. They are highly social animals, typically found in groups that can number up to 100 individuals during the dry season. This group living enhances their vigilance, as having many eyes around allows them to spot danger more easily. Additionally, capybaras are semiaquatic and can evade predators by swimming and holding their breath underwater for up to five minutes, often submerging to escape detection. Predators of capybaras include large cats, caimans, and anacondas, making these strategies essential for their survival.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara)
# - [Caviidae](https://en.wikipedia.org/w/index.php?title=Caviidae)
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus)
#
# ----
#
# Why are capybaras often considered “friendly” or “chill” animals, even getting along with other species?
# True
# # CAPYBARAS
#
#  Capybaras are often considered friendly and chill animals due to their highly social nature. They usually live in groups of around 10 to 20 individuals but can be found in much larger gatherings, sometimes exceeding 100 members, particularly during the dry season when they congregate near water sources. This social structure helps them spot predators more effectively as they rely on group vigilance for safety. Capybaras communicate through various vocalizations, aiding their interactions with both their group and other species. Their accommodating disposition allows them to coexist peacefully with other animals, which often contributes to the perception of them as gentle creatures.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara)
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus)
#
# ----
#
# How do capybaras raise their young
# True
# # CAPYBARAS
#
#  Capybaras, which are part of the family Caviidae, give birth to two or three young after a gestation period that varies among species. They are highly social animals that live in groups.
#
# ## References
# - [Caviidae](https://en.wikipedia.org/wiki/Caviidae)
#
# ----
#
# What role do capybaras play in their ecosystems?
# True
# # CAPYBARAS
#
#  Capybaras play a key role in their ecosystems, primarily as herbivores. They graze on grasses and aquatic plants, which helps maintain the health of wetland habitats where they live. By feeding on these plants, capybaras contribute to the cycling of nutrients within their environment. Additionally, their presence in groups enhances social structures and may influence the vegetation dynamics around water bodies, as they congregate during dry seasons. Their adaptations for a semiaquatic lifestyle, such as webbed feet and swimming abilities, further support their role in these ecosystems, allowing them to thrive in various aquatic surroundings.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara)
# - [Caviidae](https://en.wikipedia.org/wiki/Caviidae)
# - [Hydrochoerus](https://en.wikipedia.org/w/index.php?title=Hydrochoerus)
#
# ----
#
# How have humans affected capybara populations?
# True
# # CAPYBARAS
#
#  Capybaras are not considered a threatened species; their population is stable throughout most of their South American range. However, in some areas, hunting has reduced their numbers. Capybaras are hunted for their meat and pelts, and they are sometimes killed by humans who see their grazing as competition for livestock. In some regions, they are farmed, which has positively impacted the conservation of their wetland habitats, ensuring their survival as these habitats are protected. Additionally, capybaras have adapted well to urbanization and can be found in zoos and parks, often living for up to 12 years in captivity. They are typically docile and often allow for human interaction, such as petting and hand-feeding, although direct physical contact is usually discouraged due to health concerns such as tick-borne diseases.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara)
#
# ----
#
# Why have capybaras become such popular animals on social media?
# False
# # CAPYBARAS
#
#  The capybara is known for being the largest living rodent, native to South America, and inhabits savannas and dense forests, often near water bodies. They are highly social animals, usually living in groups of about 10 to 20 individuals, though they can also form larger groups in the dry season. These traits contribute to their social nature and endearing personality, which resonate well with social media audiences. Capybaras are also semiaquatic, excellent swimmers, and possess physical features that many find appealing, such as their stout body and blunt muzzle. Their sociable behavior and overall charm likely explain their popularity on social media platforms.
#
# More details about their social behavior can be found on the Wikipedia pages for [Capybara](https://en.wikipedia.org/wiki/Capybara) and [Caviidae](https://en.wikipedia.org/wiki/Caviidae).
#
# ## References
# - [Capybara](https://en.wikipedia.org/wiki/Capybara)
# - [Caviidae](https://en.wikipedia.org/wiki/Caviidae)
#
# ----
#
# Where do capybaras orginate from?
# True
# # CAPYBARAS
#
#  The capybara is the largest living rodent, native to South America. It inhabits savannas and dense forests, often found near bodies of water. Capybaras are highly social animals and typically live in groups, contributing to their effective communication.
#
# ## References
# - [Capybara](https://en.wikipedia.org/w/index.php?title=Capybara&action=raw)
#
# ----

# %%
# question = "where do capybaras live?"
# question = "How do capybaras raise their young?"
# question = "how do capybaras communicate within a group?"

# result = await wiki_agent.run(
#         user_prompt=question,
#         event_stream_handler=callback,
#     )
